# %% [markdown]
# # Bank Customer Churn Prediction
# ---
# ## Business Insights and Dataset Source
# ### Business Problem and Description
# Customer churn is a major challenge for banks, as it reduces their revenue and market share. It is also costly and difficult to acquire new customers than to retain existing ones. Therefore, banks need to understand the factors that influence customer churn and develop strategies to prevent it.
#
# ### Objective
# The objective of this project is to create a machine learning model that can accurately predict customer churn and provide insights into the characteristics of customers who are likely to leave the bank. The model will help the bank to target its at-risk customers and offer them personalized incentives or solutions to retain them. The model will also help the bank to improve its products and services based on the feedback and preferences of its customers. The goal is to build a machine learning model that can identify the customers who are likely to leave the bank. This can help the bank to retain its valuable customers and increase its revenue.
#
# ### Data Description
# The bank has a dataset of 10000 customers with their features and whether they have left the bank or not. The bank wants to use this dataset to build a machine learning model that can predict customer churn based on their features. The bank also wants to identify the most important features that affect customer churn and use them to segment its customers into different groups.
#
# ### Data Features
#
# - RowNumber: The record number, which has no effect on the outcome.
#
# - CustomerId: A random identifier, which has no effect on the outcome.
#
# - Surname: The customer’s surname, which has no effect on the outcome.
#
# - CreditScore: The customer’s credit score, which reflects their creditworthiness. A higher credit score means a lower risk of defaulting on loans, and thus a lower likelihood of leaving the bank.
#
# - Geography: The customer’s country of residence (Germany, France, or Spain). Different countries may have different banking preferences and regulations, which can influence the customer’s decision to stay or leave.
#
# - Gender: The customer’s gender (Female or Male). Gender may have some impact on the customer’s banking needs and expectations, which can affect their satisfaction and loyalty.
#
# - Age: The customer’s age. Older customers may have more stable and long-term relationships with the bank, while younger customers may be more willing to switch to other banks for better offers or services.
#
# - Tenure: The number of years that the customer has been with the bank. A longer tenure implies a stronger bond and trust between the customer and the bank, and thus a lower chance of leaving.
#
# - Balance: The amount of money in the customer’s account. A higher balance indicates a higher value and potential for the bank, and also a higher satisfaction and confidence from the customer. A lower balance may signal a lack of interest or engagement with the bank, and a higher possibility of leaving.
#
# - NumOfProducts: The number of products or services that the customer has purchased from the bank. A higher number of products means a more diversified and comprehensive banking experience for the customer, which can increase their retention. A lower number of products may indicate a lack of awareness or satisfaction with the bank’s offerings, which can lead to churn.
#
# - HasCrCard: Whether the customer has a credit card from the bank or not (0 = No, 1 = Yes). Having a credit card can enhance the customer’s convenience and loyalty to the bank, as well as generate more revenue for the bank. Not having a credit card may reduce the customer’s attachment and involvement with the bank.
#
# - IsActiveMember: Whether the customer is an active member of the bank or not (0 = No, 1 = Yes). Active members are more likely to use the bank’s products and services frequently, which can improve their satisfaction and retention. Inactive members may have lower engagement and interest in the bank, which can increase their churn rate.
#
# - EstimatedSalary: The customer’s estimated annual salary. A higher salary means a higher income and spending power for the customer, which can make them more valuable and loyal to the bank. A lower salary may limit the customer’s ability and willingness to use the bank’s products and services, which can make them more likely to leave.
#
# - Exited: Whether the customer has left the bank or not (0 = No, 1 = Yes). This is the target variable that we want to predict using the other features.
#
# ### Dataset Source
# Data source: Kaggle [Source Link](https://www.kaggle.com/datasets/mathchi/churn-for-bank-customers?datasetId=797699)

# %% [markdown]
# ## Library Setup

# %%
# General
import pickle
import itertools
import warnings
warnings.filterwarnings("ignore", category=DeprecationWarning) 
warnings.filterwarnings("ignore", category=FutureWarning) 
warnings.filterwarnings("ignore", category=UserWarning) 

# Pandas
import pandas as pd
pd.set_option('display.max_columns',None)
pd.set_option('display.max_rows', None)
pd.set_option('display.float_format', lambda x: '%.5f' % x)

# Numpy
import numpy as np

# Matplotlib
import matplotlib.pyplot as plt
# %matplotlib inline
plt.rcParams["font.family"] = "Sans"
plt.style.use('seaborn-poster')



# Seaborn
import seaborn as sns
sns.set()

# Sklearn
from sklearn.linear_model import LogisticRegression  
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.tree import DecisionTreeClassifier 
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import train_test_split
from sklearn import preprocessing
from sklearn.model_selection import KFold
from sklearn.model_selection import cross_val_score, GridSearchCV,train_test_split,cross_val_score
from sklearn.preprocessing import PolynomialFeatures
from sklearn.neighbors import LocalOutlierFactor 
from sklearn.preprocessing import scale,StandardScaler, MinMaxScaler,Normalizer,RobustScaler
from sklearn.preprocessing import StandardScaler
from sklearn.ensemble import RandomForestClassifier,AdaBoostClassifier,GradientBoostingClassifier

# Sklearn Metrics and Evaluation
from sklearn.metrics import classification_report
from sklearn.metrics import  accuracy_score, f1_score, precision_score,confusion_matrix, recall_score, roc_auc_score


# LightGBM
from lightgbm import LGBMClassifier

#XGBoost
from xgboost import XGBClassifier

# CatBoost
from catboost import CatBoostClassifier

# Statistics Testing
from scipy import stats
from scipy.stats import f_oneway
from scipy.stats import ttest_ind
from scipy.stats import chi2_contingency

import scikitplot as skplt

# %% [markdown]
# ## Function Setup
# Functions are handy tools for data operations. They turn common steps and commands into reusable pieces of code. This makes programming easier and less repetitive. Using functions also helps to speed up data operations and improve the workflow.

# %% [markdown]
# ### Dataset Information, Feature Checking, and Analysis

# %%
def dataInfo(X):
    print('='*10, 'DATA & FEATURE INFORMATION', '='*10)
    print(f'Data Rows: {X.shape[0]}')
    print(f'Data Columns: {X.shape[1]}')
    print(f'Duplicated Values: {X.duplicated().sum()}')
    missing_val = X.isnull().sum()
    missing_val_percentage = missing_val/len(X)*100
    data_type = X.dtypes
    unique_val = X.nunique()
    return pd.DataFrame({
        'Missing_val' : missing_val,
        'Missing_percentage' : missing_val_percentage,
        'Data_type' : data_type,
        'Unique_values' : unique_val
    }).sort_values('Missing_percentage',ascending=False)

# %% [markdown]
# ### Checking Outlier in Data and Returning It

# %%
def dataOutlier(X, col):
    q1 = X[col].quantile(0.25) # Finding the first quartile
    q3 = X[col].quantile(0.75) # Finding the third quartile
    iqr_val = stats.iqr(X[col]) # Finding the interquartile range
    lower = q1 - (1.5*iqr_val) # Lower limit for detecting outliers in the data
    upper = q3 + (1.5*iqr_val) # Upper limit for detecting outliers in the data
    
    outlier_list = X[col].apply(lambda x: 'outlier' if x < lower or x > upper else 'not-outlier')
    print(f'outlier lower limit: {lower}\noutlier upper limit: {upper}')
    return outlier_list

# %% [markdown]
# ### Checking Outlier Using LOF method

# %%
def lof_observation(df):
    numerics = ['int16', 'int32', 'int64', 'float16', 'float32', 'float64']
    df_num_cols = df.select_dtypes(include=numerics)
    df_outlier = df_num_cols.astype("float64")
    clf = LocalOutlierFactor(n_neighbors = 20, contamination = 0.1)
    clf.fit_predict(df_outlier)
    df_scores = clf.negative_outlier_factor_
    scores_df = pd.DataFrame(np.sort(df_scores))
    
    scores_df.plot(stacked=True, xlim = [0,20], color='r', title='Visualization of outliers according to the LOF method', style = '.-');                # first 20 observe
    th_val = np.sort(df_scores)[2]
    outliers = df_scores > th_val
    df = df.drop(df_outlier[~outliers].index)
    df.shape
    return df

# %% [markdown]
# ### Returning Unique Values in Data

# %%
def dataUnique(X):
    for x in X.columns:
        print(f'========== {x} ==========')
        print(f'{X[x].unique()}\n') # Printing all the unique values in the columns

# %% [markdown]
# ### Data Visualization (Used Mostly to See The Data Distribution and Outlier Existence)

# %%
def hist_boxplot(df, x_col, y_col=None, hue_col=None):
    color = '#F84030'
    if y_col is None: 
        plt.figure(figsize=(10,10))
        plt.subplot(211)
        sns.boxplot(data=df, x=x_col, color=color)
        
        plt.subplot(212)
        sns.histplot(data=df, x=x_col, color=color)
        plt.tight_layout()
        plt.show()
        
    elif hue_col is None:
        plt.figure(figsize=(10,10))
        plt.subplot(211)
        sns.boxplot(data=df, x=x_col, y=y_col, color=color)
        
        plt.subplot(212)
        sns.histplot(data=df, x=x_col, y=y_col, color=color)
        plt.tight_layout()
        plt.show()
        
    else:
        plt.figure(figsize=(10,10))
        plt.subplot(211)
        sns.boxplot(data=df, x=x_col, y=y_col, hue=hue_col, color=color)
        
        plt.subplot(212)
        sns.histplot(data=df, x=x_col, y=y_col, hue=hue_col, color=color)
        plt.tight_layout()
        plt.show()

# %% [markdown]
# ### Another Data Visualization (Used to See The Corelation of Certain Variable, Mostly Between Predictor and Target)

# %%
#catergoric vs categoric
#predictor,target
def plot_category_category(df, predictor, target):
    ax = ((df.groupby([predictor])[target].mean())/((df.groupby([predictor])[target].mean()).sum())*100).plot(kind='bar',figsize=(10,8), color = '#F84030')
    abs_values = round(((df.groupby([predictor])[target].mean())/((df.groupby([predictor])[target].mean()).sum())*100),1)
    ax.bar_label(container=ax.containers[0], labels=abs_values)  

    plt.xticks(rotation=0);
    plt.ylabel('Churn Rate (%)',fontsize=12)
    plt.title(f'{predictor} vs Churn Rate (%)',fontsize=12)
    plt.xlabel(predictor,fontsize=12)
    plt.ylim(0,100)

    plt.show()

# %%
def plot_num_category(df, numeric, category):
    ax = (df.groupby([category])[numeric].median()).plot(kind='bar',figsize=(10,8), color = '#F84030')
    abs_values = round((df.groupby([category])[numeric].median()),1)
    ax.bar_label(container=ax.containers[0], labels=abs_values)
    
    plt.title(f'{numeric} vs {category}',fontsize=12)
    plt.ylabel(category,fontsize=12)
    plt.xlabel(numeric,fontsize=12)
    plt.xticks(rotation=0);
    plt.ylim(0,max(abs_values)+100)
    plt.show()

# %% [markdown]
# ### Statistical Analysis (Analysis of Variance and Chi-Square Test)
# ANOVA (analysis of variance) is a statistical test that compares the means of multiple groups to determine if there are significant differences between them. The chi-square test is a statistical test that compares observed frequencies in a sample to expected frequencies in a population to determine if there is a significant difference between them.
#
# ANOVA is used for continuous data and assumes normality and equal variances, while the chi-square test is used for categorical data and makes no assumptions about the data. ANOVA produces an F-value and p-value, while the chi-square test produces a chi-square statistic and p-value.

# %%
def anova(df, predictor_col, target_col):
    group1 = df[df[target_col]==1][predictor_col]
    group2 = df[df[target_col]==0][predictor_col]

    alpha = 0.05
    ftest, p_value = f_oneway(group1, group2)

    if p_value < alpha:
        print(f'Conclusion: p-value {p_value} is less than alpha {alpha}, ftest = {ftest}')
        print('There is a significant difference in the target based on the predictor.')
        print()
    else:
        print(f'Conclusion: p-value {p_value} is greater than alpha {alpha}, ftest = {ftest}')
        print('There is no significant difference in the target based on the predictor.')
        print()

# %%
def chi_test(df, predictor_col, target_col):
    obs = pd.crosstab(df[predictor_col], df[target_col])
    chi2, p, dof, expected = chi2_contingency(obs)
    alpha = 0.05

    if p < alpha:
        print(f'===== {predictor_col} =====')
        print('Number Expected:')
        print(expected)
        print()
        print(f'Chi-square Statistic: {chi2}, p-value: {p} less than {alpha}')
        print('There is a significant difference in the target based on the predictor.')
        print()
    else:
        print(f'===== {predictor_col} =====')
        print('Number Expected:')
        print(expected)
        print()
        print(f'Chi-square Statistic: {chi2}, p-value: {p} greater than {alpha}')
        print('There is no significant difference in the target based on the predictor.')
        print()

# %% [markdown]
# ## Data Preparation

# %% [markdown]
# ### Import Data

# %%
data = pd.read_csv('data/churn.csv')

# %%
data.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure      Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2      0.00000              1          1               1
# 1       1  83807.86000              1          0               1
# 2       8 159660.80000              3          1               0
# 3       1      0.00000              2          0               0
# 4       2 125510.82000              1          1               1
#
#    EstimatedSalary  Exited
# 0     101348.88000       1
# 1     112542.58000       0
# 2     113931.57000       1
# 3      93826.63000       0
# 4      79084.10000       0

# %% [markdown]
# ## Data Checking

# %% [markdown]
# ### Checking for The Data Dimension, Missing Data, and Wrong Input in Data

# %%
dataInfo(data)
# Out:
# ========== DATA & FEATURE INFORMATION ==========
# Data Rows: 10000
# Data Columns: 14
# Duplicated Values: 0
#                  Missing_val  Missing_percentage Data_type  Unique_values
# RowNumber                  0             0.00000     int64          10000
# CustomerId                 0             0.00000     int64          10000
# Surname                    0             0.00000    object           2932
# CreditScore                0             0.00000     int64            460
# Geography                  0             0.00000    object              3
# Gender                     0             0.00000    object              2
# Age                        0             0.00000     int64             70
# Tenure                     0             0.00000     int64             11
# Balance                    0             0.00000   float64           6382
# NumOfProducts              0             0.00000     int64              4
# HasCrCard                  0             0.00000     int64              2
# IsActiveMember             0             0.00000     int64              2
# EstimatedSalary            0             0.00000   float64           9999
# Exited                     0             0.00000     int64              2

# %%
dataUnique(data)
# Out:
# ========== RowNumber ==========
# [    1     2     3 ...  9998  9999 10000]
#
# ========== CustomerId ==========
# [15634602 15647311 15619304 ... 15584532 15682355 15628319]
#
# ========== Surname ==========
# ['Hargrave' 'Hill' 'Onio' ... 'Kashiwagi' 'Aldridge' 'Burbidge']
#
# ========== CreditScore ==========
# [619 608 502 699 850 645 822 376 501 684 528 497 476 549 635 616 653 587
#  726 732 636 510 669 846 577 756 571 574 411 591 533 553 520 722 475 490
#  804 582 472 465 556 834 660 776 829 637 550 698 585 788 655 601 656 725
#  511 614 742 687 555 603 751 581 735 661 675 738 813 657 604 519 664 678
#  757 416 665 777 543 506 493 652 750 729 646 647 808 524 769 730 515 773
#  814 710 413 623 670 622 785 605 479 685 538 562 721 628 668 828 674 625
#  432 770 758 795 686 789 589 461 584 579 663 682 793 691 485 650 754 535
#  716 539 706 586 631 717 800 683 704 615 667 484 480 578 512 606 597 778
#  514 525 715 580 807 521 759 516 711 618 643 671 689 620 676 572 695 592
#  567 694 547 594 673 610 767 763 712 703 662 659 523 772 545 634 739 771
#  681 544 696 766 727 693 557 531 498 651 791 733 811 707 714 782 775 799
#  602 744 588 747 583 627 731 629 438 642 806 474 559 429 680 749 734 644
#  626 649 805 718 840 630 654 762 568 613 522 737 648 443 640 540 460 593
#  801 611 802 745 483 690 492 709 705 560 752 701 537 487 596 702 486 724
#  548 464 790 534 748 494 590 468 509 818 816 536 753 774 621 569 658 798
#  641 542 692 639 765 570 638 599 632 779 527 564 833 504 842 508 417 598
#  741 607 761 848 546 439 755 760 526 713 700 666 566 495 688 612 477 427
#  839 819 720 459 503 624 529 563 482 796 445 746 786 554 672 787 499 844
#  450 815 838 803 736 633 600 679 517 792 743 488 421 841 708 507 505 456
#  435 561 518 565 728 784 552 609 764 697 723 551 444 719 496 541 830 812
#  677 420 595 617 809 500 826 434 513 478 797 363 399 463 780 452 575 837
#  794 824 428 823 781 849 489 431 457 768 831 359 820 573 576 558 817 449
#  440 415 821 530 350 446 425 740 481 783 358 845 451 458 469 423 404 836
#  473 835 466 491 351 827 843 365 532 414 453 471 401 810 832 470 447 422
#  825 430 436 426 408 847 418 437 410 454 407 455 462 386 405 383 395 467
#  433 442 424 448 441 367 412 382 373 419]
#
# ========== Geography ==========
# ['France' 'Spain' 'Germany']
#
# ========== Gender ==========
# ['Female' 'Male']
#
# ========== Age ==========
# [42 41 39 43 44 50 29 27 31 24 34 25 35 45 58 32 38 46 36 33 40 51 61 49
#  37 19 66 56 26 21 55 75 22 30 28 65 48 52 57 73 47 54 72 20 67 79 62 53
#  80 59 68 23 60 70 63 64 18 82 69 74 71 76 77 88 85 84 78 81 92 83]
#
# ========== Tenure ==========
# [ 2  1  8  7  4  6  3 10  5  9  0]
#
# ========== Balance ==========
# [     0.    83807.86 159660.8  ...  57369.61  75075.31 130142.79]
#
# ========== NumOfProducts ==========
# [1 3 2 4]
#
# ========== HasCrCard ==========
# [1 0]
#
# ========== IsActiveMember ==========
# [1 0]
#
# ========== EstimatedSalary ==========
# [101348.88 112542.58 113931.57 ...  42085.58  92888.52  38190.78]
#
# ========== Exited ==========
# [1 0]

# %% [markdown]
# ### First Observation
# 1. The dataset consists of 10000 observations with 14 variables each
# 2. The data is clean and complete, with no missing or duplicated values
# 3. Target data is called "Exited"
# 4. Some data type might need changing
# 5. Gender and Geography can be encoded

# %%
TARGET = "Exited"

# %%
data_new = data.copy()
data_new['Tenure'] =  data_new.Tenure.astype(float)
data_new['NumOfProducts'] =  data_new.NumOfProducts.astype(float)

# %%
data_new.head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure      Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0 2.00000      0.00000        1.00000          1               1
# 1 1.00000  83807.86000        1.00000          0               1
# 2 8.00000 159660.80000        3.00000          1               0
# 3 1.00000      0.00000        2.00000          0               0
# 4 2.00000 125510.82000        1.00000          1               1
#
#    EstimatedSalary  Exited
# 0     101348.88000       1
# 1     112542.58000       0
# 2     113931.57000       1
# 3      93826.63000       0
# 4      79084.10000       0

# %% [markdown]
# ### Data Descriptive Statistics

# %%
numerical = ['CreditScore',
             'Age',
             'Tenure',
             'Balance',
             'NumOfProducts',
             'EstimatedSalary']
categorical =['RowNumber',
              'CustomerId',
              'Surname',
              'Geography',
              'Gender',
              'HasCrCard',
              'IsActiveMember',
              'Exited']

# %%
data_new[numerical].describe().T
# Out:
#                       count         mean         std       min         25%  \
# CreditScore     10000.00000    650.52880    96.65330 350.00000   584.00000
# Age             10000.00000     38.92180    10.48781  18.00000    32.00000
# Tenure          10000.00000      5.01280     2.89217   0.00000     3.00000
# Balance         10000.00000  76485.88929 62397.40520   0.00000     0.00000
# NumOfProducts   10000.00000      1.53020     0.58165   1.00000     1.00000
# EstimatedSalary 10000.00000 100090.23988 57510.49282  11.58000 51002.11000
#
#                          50%          75%          max
# CreditScore        652.00000    718.00000    850.00000
# Age                 37.00000     44.00000     92.00000
# Tenure               5.00000      7.00000     10.00000
# Balance          97198.54000 127644.24000 250898.09000
# NumOfProducts        1.00000      2.00000      4.00000
# EstimatedSalary 100193.91500 149388.24750 199992.48000

# %%
# Select rows where is 1 (Exited)
df_zero = data_new.query('Exited == 1')

# Count occurrences of each value
counts = df_zero['Exited'].value_counts()

plot_exited = pd.DataFrame({'Yes' : counts,'No' : len(data_new) - counts})

# Plot as pie chart
plot_exited.T.plot(kind = 'pie',subplots=True, legend =False, title = 'Exited', figsize = (6,6),colors=['#F84030','#F2F2F2'], 
        shadow=True,
        autopct='%1.1f%%',
        textprops={'fontsize': 16})
# Out:
# array([<Axes: ylabel='1'>], dtype=object)

# %%
data_new[categorical].describe().T
# Out:
#                      count           mean         std            min  \
# RowNumber      10000.00000     5000.50000  2886.89568        1.00000
# CustomerId     10000.00000 15690940.56940 71936.18612 15565701.00000
# HasCrCard      10000.00000        0.70550     0.45584        0.00000
# IsActiveMember 10000.00000        0.51510     0.49980        0.00000
# Exited         10000.00000        0.20370     0.40277        0.00000
#
#                           25%            50%            75%            max
# RowNumber          2500.75000     5000.50000     7500.25000    10000.00000
# CustomerId     15628528.25000 15690738.00000 15753233.75000 15815690.00000
# HasCrCard             0.00000        1.00000        1.00000        1.00000
# IsActiveMember        0.00000        1.00000        1.00000        1.00000
# Exited                0.00000        0.00000        0.00000        1.00000

# %%
(data_new[data_new[categorical] == 1][categorical].count())/len(data_new)*100
# Out:
# RowNumber         0.01000
# CustomerId        0.00000
# Surname           0.00000
# Geography         0.00000
# Gender            0.00000
# HasCrCard        70.55000
# IsActiveMember   51.51000
# Exited           20.37000
# dtype: float64

# %% [markdown]
# ### Second Observation
# 1. The average credit score of the customers is 650.53, which is considered fair.
# 2. The credit score ranges from 350 to 850, with 850 being the highest possible score.
# 3. The average age of the customers is 38.92 years, with a minimum of 18 and a maximum of 92.
# 4. The average tenure of the customers is 5.01 years, meaning they have been with the company for about 5 years on average. The tenure ranges from 0 to 10 years.
# 5. The average balance of the customers is 76485.89, with a large variation of 62397.41. The balance ranges from 0 to 250898.09, with some customers having no balance at all.
# 6. The average number of products used by the customers is 1.53, with a standard deviation of 0.58. The number of products ranges from 1 to 4, with most customers using either 1 or 2 products.
# 7. The average estimated salary of the customers is 100090.24, with a standard deviation of 57510.49. The estimated salary ranges from 11.58 to 199992.48, with a wide distribution of values.
# 8. The data also shows that 20.4% of the customers exited the company, which is a high churn rate. This could indicate that the company is not meeting the needs or expectations of its customers, or that there are better alternatives in the market.
# 9. 70.55% customer has a credit card, 51.51% customer is an active member

# %% [markdown]
# ## Exploratory Data Analysis

# %%
lof_observation(data_new).head()
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          1    15634602  Hargrave          619    France  Female   42
# 1          2    15647311      Hill          608     Spain  Female   41
# 2          3    15619304      Onio          502    France  Female   42
# 3          4    15701354      Boni          699    France  Female   39
# 4          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure      Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0 2.00000      0.00000        1.00000          1               1
# 1 1.00000  83807.86000        1.00000          0               1
# 2 8.00000 159660.80000        3.00000          1               0
# 3 1.00000      0.00000        2.00000          0               0
# 4 2.00000 125510.82000        1.00000          1               1
#
#    EstimatedSalary  Exited
# 0     101348.88000       1
# 1     112542.58000       0
# 2     113931.57000       1
# 3      93826.63000       0
# 4      79084.10000       0

# %% [markdown]
# ### Profile Analysis of The Costumer

# %% [markdown]
# #### 1. CreditScore vs Exited

# %%
hist_boxplot(data_new,'CreditScore')

# %%
plot_num_category(data_new,'CreditScore',TARGET)

# %%
anova(data_new,'CreditScore',TARGET)
# Out:
# Conclusion: p-value 0.006738213892205324 is less than alpha 0.05, ftest = 7.344522163758249
# There is a significant difference in the target based on the predictor.

# %%
dataOutlier(data_new, 'CreditScore')
# Out:
# outlier lower limit: 383.0
# outlier upper limit: 919.0
# 0       not-outlier
# 1       not-outlier
# 2       not-outlier
# 3       not-outlier
# 4       not-outlier
# 5       not-outlier
# 6       not-outlier
# 7           outlier
# 8       not-outlier
# 9       not-outlier
# 10      not-outlier
# 11      not-outlier
# 12      not-outlier
# 13      not-outlier
# 14      not-outlier
# 15      not-outlier
# 16      not-outlier
# 17      not-outlier
# 18      not-outlier
# 19      not-outlier
# 20      not-outlier
# 21      not-outlier
# 22      not-outlier
# 23      not-outlier
# 24      not-outlier
# 25      not-outlier
# 26      not-outlier
# 27      not-outlier
# 28      not-outlier
# 29      not-outlier
# 30      not-outlier
# 31      not-outlier
# 32      not-outlier
# 33      not-outlier
# 34      not-outlier
# 35      not-outlier
# 36      not-outlier
# 37      not-outlier
# 38      not-outlier
# 39      not-outlier
# 40      not-outlier
# 41      not-outlier
# 42      not-outlier
# 43      not-outlier
# 44      not-outlier
# 45      not-outlier
# 46      not-outlier
# 47      not-outlier
# 48      not-outlier
# 49      not-outlier
# 50      not-outlier
# 51      not-outlier
# 52      not-outlier
# 53      not-outlier
# 54      not-outlier
# 55      not-outlier
# 56      not-outlier
# 57      not-outlier
# 58      not-outlier
# 59      not-outlier
# 60      not-outlier
# 61      not-outlier
# 62      not-outlier
# 63      not-outlier
# 64      not-outlier
# 65      not-outlier
# 66      not-outlier
# 67      not-outlier
# 68      not-outlier
# 69      not-outlier
# 70      not-outlier
# 71      not-outlier
# 72      not-outlier
# 73      not-outlier
# 74      not-outlier
# 75      not-outlier
# 76      not-outlier
# 77      not-outlier
# 78      not-outlier
# 79      not-outlier
# 80      not-outlier
# 81      not-outlier
# 82      not-outlier
# 83      not-outlier
# 84      not-outlier
# 85      not-outlier
# 86      not-outlier
# 87      not-outlier
# 88      not-outlier
# 89      not-outlier
# 90      not-outlier
# 91      not-outlier
# 92      not-outlier
# 93      not-outlier
# 94      not-outlier
# 95      not-outlier
# 96      not-outlier
# 97      not-outlier
# 98      not-outlier
# 99      not-outlier
# 100     not-outlier
# 101     not-outlier
# 102     not-outlier
# 103     not-outlier
# 104     not-outlier
# 105     not-outlier
# 106     not-outlier
# 107     not-outlier
# 108     not-outlier
# 109     not-outlier
# 110     not-outlier
# 111     not-outlier
# 112     not-outlier
# 113     not-outlier
# 114     not-outlier
# 115     not-outlier
# 116     not-outlier
# 117     not-outlier
# 118     not-outlier
# 119     not-outlier
# 120     not-outlier
# 121     not-outlier
# 122     not-outlier
# 123     not-outlier
# 124     not-outlier
# 125     not-outlier
# 126     not-outlier
# 127     not-outlier
# 128     not-outlier
# 129     not-outlier
# 130     not-outlier
# 131     not-outlier
# 132     not-outlier
# 133     not-outlier
# 134     not-outlier
# 135     not-outlier
# 136     not-outlier
# 137     not-outlier
# 138     not-outlier
# 139     not-outlier
# 140     not-outlier
# 141     not-outlier
# 142     not-outlier
# 143     not-outlier
# 144     not-outlier
# 145     not-outlier
# 146     not-outlier
# 147     not-outlier
# 148     not-outlier
# 149     not-outlier
# 150     not-outlier
# 151     not-outlier
# 152     not-outlier
# 153     not-outlier
# 154     not-outlier
# 155     not-outlier
# 156     not-outlier
# 157     not-outlier
# 158     not-outlier
# 159     not-outlier
# 160     not-outlier
# 161     not-outlier
# 162     not-outlier
# 163     not-outlier
# 164     not-outlier
# 165     not-outlier
# 166     not-outlier
# 167     not-outlier
# 168     not-outlier
# 169     not-outlier
# 170     not-outlier
# 171     not-outlier
# 172     not-outlier
# 173     not-outlier
# 174     not-outlier
# 175     not-outlier
# 176     not-outlier
# 177     not-outlier
# 178     not-outlier
# 179     not-outlier
# 180     not-outlier
# 181     not-outlier
# 182     not-outlier
# 183     not-outlier
# 184     not-outlier
# 185     not-outlier
# 186     not-outlier
# 187     not-outlier
# 188     not-outlier
# 189     not-outlier
# 190     not-outlier
# 191     not-outlier
# 192     not-outlier
# 193     not-outlier
# 194     not-outlier
# 195     not-outlier
# 196     not-outlier
# 197     not-outlier
# 198     not-outlier
# 199     not-outlier
# 200     not-outlier
# 201     not-outlier
# 202     not-outlier
# 203     not-outlier
# 204     not-outlier
# 205     not-outlier
# 206     not-outlier
# 207     not-outlier
# 208     not-outlier
# 209     not-outlier
# 210     not-outlier
# 211     not-outlier
# 212     not-outlier
# 213     not-outlier
# 214     not-outlier
# 215     not-outlier
# 216     not-outlier
# 217     not-outlier
# 218     not-outlier
# 219     not-outlier
# 220     not-outlier
# 221     not-outlier
# 222     not-outlier
# 223     not-outlier
# 224     not-outlier
# 225     not-outlier
# 226     not-outlier
# 227     not-outlier
# 228     not-outlier
# 229     not-outlier
# 230     not-outlier
# 231     not-outlier
# 232     not-outlier
# 233     not-outlier
# 234     not-outlier
# 235     not-outlier
# 236     not-outlier
# 237     not-outlier
# 238     not-outlier
# 239     not-outlier
# 240     not-outlier
# 241     not-outlier
# 242     not-outlier
# 243     not-outlier
# 244     not-outlier
# 245     not-outlier
# 246     not-outlier
# 247     not-outlier
# 248     not-outlier
# 249     not-outlier
# 250     not-outlier
# 251     not-outlier
# 252     not-outlier
# 253     not-outlier
# 254     not-outlier
# 255     not-outlier
# 256     not-outlier
# 257     not-outlier
# 258     not-outlier
# 259     not-outlier
# 260     not-outlier
# 261     not-outlier
# 262     not-outlier
# 263     not-outlier
# 264     not-outlier
# 265     not-outlier
# 266     not-outlier
# 267     not-outlier
# 268     not-outlier
# 269     not-outlier
# 270     not-outlier
# 271     not-outlier
# 272     not-outlier
# 273     not-outlier
# 274     not-outlier
# 275     not-outlier
# 276     not-outlier
# 277     not-outlier
# 278     not-outlier
# 279     not-outlier
# 280     not-outlier
# 281     not-outlier
# 282     not-outlier
# 283     not-outlier
# 284     not-outlier
# 285     not-outlier
# 286     not-outlier
# 287     not-outlier
# 288     not-outlier
# 289     not-outlier
# 290     not-outlier
# 291     not-outlier
# 292     not-outlier
# 293     not-outlier
# 294     not-outlier
# 295     not-outlier
# 296     not-outlier
# 297     not-outlier
# 298     not-outlier
# 299     not-outlier
# 300     not-outlier
# 301     not-outlier
# 302     not-outlier
# 303     not-outlier
# 304     not-outlier
# 305     not-outlier
# 306     not-outlier
# 307     not-outlier
# 308     not-outlier
# 309     not-outlier
# 310     not-outlier
# 311     not-outlier
# 312     not-outlier
# 313     not-outlier
# 314     not-outlier
# 315     not-outlier
# 316     not-outlier
# 317     not-outlier
# 318     not-outlier
# 319     not-outlier
# 320     not-outlier
# 321     not-outlier
# 322     not-outlier
# 323     not-outlier
# 324     not-outlier
# 325     not-outlier
# 326     not-outlier
# 327     not-outlier
# 328     not-outlier
# 329     not-outlier
# 330     not-outlier
# 331     not-outlier
# 332     not-outlier
# 333     not-outlier
# 334     not-outlier
# 335     not-outlier
# 336     not-outlier
# 337     not-outlier
# 338     not-outlier
# 339     not-outlier
# 340     not-outlier
# 341     not-outlier
# 342     not-outlier
# 343     not-outlier
# 344     not-outlier
# 345     not-outlier
# 346     not-outlier
# 347     not-outlier
# 348     not-outlier
# 349     not-outlier
# 350     not-outlier
# 351     not-outlier
# 352     not-outlier
# 353     not-outlier
# 354     not-outlier
# 355     not-outlier
# 356     not-outlier
# 357     not-outlier
# 358     not-outlier
# 359     not-outlier
# 360     not-outlier
# 361     not-outlier
# 362     not-outlier
# 363     not-outlier
# 364     not-outlier
# 365     not-outlier
# 366     not-outlier
# 367     not-outlier
# 368     not-outlier
# 369     not-outlier
# 370     not-outlier
# 371     not-outlier
# 372     not-outlier
# 373     not-outlier
# 374     not-outlier
# 375     not-outlier
# 376     not-outlier
# 377     not-outlier
# 378     not-outlier
# 379     not-outlier
# 380     not-outlier
# 381     not-outlier
# 382     not-outlier
# 383     not-outlier
# 384     not-outlier
# 385     not-outlier
# 386     not-outlier
# 387     not-outlier
# 388     not-outlier
# 389     not-outlier
# 390     not-outlier
# 391     not-outlier
# 392     not-outlier
# 393     not-outlier
# 394     not-outlier
# 395     not-outlier
# 396     not-outlier
# 397     not-outlier
# 398     not-outlier
# 399     not-outlier
# 400     not-outlier
# 401     not-outlier
# 402     not-outlier
# 403     not-outlier
# 404     not-outlier
# 405     not-outlier
# 406     not-outlier
# 407     not-outlier
# 408     not-outlier
# 409     not-outlier
# 410     not-outlier
# 411     not-outlier
# 412     not-outlier
# 413     not-outlier
# 414     not-outlier
# 415     not-outlier
# 416     not-outlier
# 417     not-outlier
# 418     not-outlier
# 419     not-outlier
# 420     not-outlier
# 421     not-outlier
# 422     not-outlier
# 423     not-outlier
# 424     not-outlier
# 425     not-outlier
# 426     not-outlier
# 427     not-outlier
# 428     not-outlier
# 429     not-outlier
# 430     not-outlier
# 431     not-outlier
# 432     not-outlier
# 433     not-outlier
# 434     not-outlier
# 435     not-outlier
# 436     not-outlier
# 437     not-outlier
# 438     not-outlier
# 439     not-outlier
# 440     not-outlier
# 441     not-outlier
# 442     not-outlier
# 443     not-outlier
# 444     not-outlier
# 445     not-outlier
# 446     not-outlier
# 447     not-outlier
# 448     not-outlier
# 449     not-outlier
# 450     not-outlier
# 451     not-outlier
# 452     not-outlier
# 453     not-outlier
# 454     not-outlier
# 455     not-outlier
# 456     not-outlier
# 457     not-outlier
# 458     not-outlier
# 459     not-outlier
# 460     not-outlier
# 461     not-outlier
# 462     not-outlier
# 463     not-outlier
# 464     not-outlier
# 465     not-outlier
# 466     not-outlier
# 467     not-outlier
# 468     not-outlier
# 469     not-outlier
# 470     not-outlier
# 471     not-outlier
# 472     not-outlier
# 473     not-outlier
# 474     not-outlier
# 475     not-outlier
# 476     not-outlier
# 477     not-outlier
# 478     not-outlier
# 479     not-outlier
# 480     not-outlier
# 481     not-outlier
# 482     not-outlier
# 483     not-outlier
# 484     not-outlier
# 485     not-outlier
# 486     not-outlier
# 487     not-outlier
# 488     not-outlier
# 489     not-outlier
# 490     not-outlier
# 491     not-outlier
# 492     not-outlier
# 493     not-outlier
# 494     not-outlier
# 495     not-outlier
# 496     not-outlier
# 497     not-outlier
# 498     not-outlier
# 499     not-outlier
# 500     not-outlier
# 501     not-outlier
# 502     not-outlier
# 503     not-outlier
# 504     not-outlier
# 505     not-outlier
# 506     not-outlier
# 507     not-outlier
# 508     not-outlier
# 509     not-outlier
# 510     not-outlier
# 511     not-outlier
# 512     not-outlier
# 513     not-outlier
# 514     not-outlier
# 515     not-outlier
# 516     not-outlier
# 517     not-outlier
# 518     not-outlier
# 519     not-outlier
# 520     not-outlier
# 521     not-outlier
# 522     not-outlier
# 523     not-outlier
# 524     not-outlier
# 525     not-outlier
# 526     not-outlier
# 527     not-outlier
# 528     not-outlier
# 529     not-outlier
# 530     not-outlier
# 531     not-outlier
# 532     not-outlier
# 533     not-outlier
# 534     not-outlier
# 535     not-outlier
# 536     not-outlier
# 537     not-outlier
# 538     not-outlier
# 539     not-outlier
# 540     not-outlier
# 541     not-outlier
# 542     not-outlier
# 543     not-outlier
# 544     not-outlier
# 545     not-outlier
# 546     not-outlier
# 547     not-outlier
# 548     not-outlier
# 549     not-outlier
# 550     not-outlier
# 551     not-outlier
# 552     not-outlier
# 553     not-outlier
# 554     not-outlier
# 555     not-outlier
# 556     not-outlier
# 557     not-outlier
# 558     not-outlier
# 559     not-outlier
# 560     not-outlier
# 561     not-outlier
# 562     not-outlier
# 563     not-outlier
# 564     not-outlier
# 565     not-outlier
# 566     not-outlier
# 567     not-outlier
# 568     not-outlier
# 569     not-outlier
# 570     not-outlier
# 571     not-outlier
# 572     not-outlier
# 573     not-outlier
# 574     not-outlier
# 575     not-outlier
# 576     not-outlier
# 577     not-outlier
# 578     not-outlier
# 579     not-outlier
# 580     not-outlier
# 581     not-outlier
# 582     not-outlier
# 583     not-outlier
# 584     not-outlier
# 585     not-outlier
# 586     not-outlier
# 587     not-outlier
# 588     not-outlier
# 589     not-outlier
# 590     not-outlier
# 591     not-outlier
# 592     not-outlier
# 593     not-outlier
# 594     not-outlier
# 595     not-outlier
# 596     not-outlier
# 597     not-outlier
# 598     not-outlier
# 599     not-outlier
# 600     not-outlier
# 601     not-outlier
# 602     not-outlier
# 603     not-outlier
# 604     not-outlier
# 605     not-outlier
# 606     not-outlier
# 607     not-outlier
# 608     not-outlier
# 609     not-outlier
# 610     not-outlier
# 611     not-outlier
# 612     not-outlier
# 613     not-outlier
# 614     not-outlier
# 615     not-outlier
# 616     not-outlier
# 617     not-outlier
# 618     not-outlier
# 619     not-outlier
# 620     not-outlier
# 621     not-outlier
# 622     not-outlier
# 623     not-outlier
# 624     not-outlier
# 625     not-outlier
# 626     not-outlier
# 627     not-outlier
# 628     not-outlier
# 629     not-outlier
# 630     not-outlier
# 631     not-outlier
# 632     not-outlier
# 633     not-outlier
# 634     not-outlier
# 635     not-outlier
# 636     not-outlier
# 637     not-outlier
# 638     not-outlier
# 639     not-outlier
# 640     not-outlier
# 641     not-outlier
# 642     not-outlier
# 643     not-outlier
# 644     not-outlier
# 645     not-outlier
# 646     not-outlier
# 647     not-outlier
# 648     not-outlier
# 649     not-outlier
# 650     not-outlier
# 651     not-outlier
# 652     not-outlier
# 653     not-outlier
# 654     not-outlier
# 655     not-outlier
# 656     not-outlier
# 657     not-outlier
# 658     not-outlier
# 659     not-outlier
# 660     not-outlier
# 661     not-outlier
# 662     not-outlier
# 663     not-outlier
# 664     not-outlier
# 665     not-outlier
# 666     not-outlier
# 667     not-outlier
# 668     not-outlier
# 669     not-outlier
# 670     not-outlier
# 671     not-outlier
# 672     not-outlier
# 673     not-outlier
# 674     not-outlier
# 675     not-outlier
# 676     not-outlier
# 677     not-outlier
# 678     not-outlier
# 679     not-outlier
# 680     not-outlier
# 681     not-outlier
# 682     not-outlier
# 683     not-outlier
# 684     not-outlier
# 685     not-outlier
# 686     not-outlier
# 687     not-outlier
# 688     not-outlier
# 689     not-outlier
# 690     not-outlier
# 691     not-outlier
# 692     not-outlier
# 693     not-outlier
# 694     not-outlier
# 695     not-outlier
# 696     not-outlier
# 697     not-outlier
# 698     not-outlier
# 699     not-outlier
# 700     not-outlier
# 701     not-outlier
# 702     not-outlier
# 703     not-outlier
# 704     not-outlier
# 705     not-outlier
# 706     not-outlier
# 707     not-outlier
# 708     not-outlier
# 709     not-outlier
# 710     not-outlier
# 711     not-outlier
# 712     not-outlier
# 713     not-outlier
# 714     not-outlier
# 715     not-outlier
# 716     not-outlier
# 717     not-outlier
# 718     not-outlier
# 719     not-outlier
# 720     not-outlier
# 721     not-outlier
# 722     not-outlier
# 723     not-outlier
# 724     not-outlier
# 725     not-outlier
# 726     not-outlier
# 727     not-outlier
# 728     not-outlier
# 729     not-outlier
# 730     not-outlier
# 731     not-outlier
# 732     not-outlier
# 733     not-outlier
# 734     not-outlier
# 735     not-outlier
# 736     not-outlier
# 737     not-outlier
# 738     not-outlier
# 739     not-outlier
# 740     not-outlier
# 741     not-outlier
# 742     not-outlier
# 743     not-outlier
# 744     not-outlier
# 745     not-outlier
# 746     not-outlier
# 747     not-outlier
# 748     not-outlier
# 749     not-outlier
# 750     not-outlier
# 751     not-outlier
# 752     not-outlier
# 753     not-outlier
# 754     not-outlier
# 755     not-outlier
# 756     not-outlier
# 757     not-outlier
# 758     not-outlier
# 759     not-outlier
# 760     not-outlier
# 761     not-outlier
# 762     not-outlier
# 763     not-outlier
# 764     not-outlier
# 765     not-outlier
# 766     not-outlier
# 767     not-outlier
# 768     not-outlier
# 769     not-outlier
# 770     not-outlier
# 771     not-outlier
# 772     not-outlier
# 773     not-outlier
# 774     not-outlier
# 775     not-outlier
# 776     not-outlier
# 777     not-outlier
# 778     not-outlier
# 779     not-outlier
# 780     not-outlier
# 781     not-outlier
# 782     not-outlier
# 783     not-outlier
# 784     not-outlier
# 785     not-outlier
# 786     not-outlier
# 787     not-outlier
# 788     not-outlier
# 789     not-outlier
# 790     not-outlier
# 791     not-outlier
# 792     not-outlier
# 793     not-outlier
# 794     not-outlier
# 795     not-outlier
# 796     not-outlier
# 797     not-outlier
# 798     not-outlier
# 799     not-outlier
# 800     not-outlier
# 801     not-outlier
# 802     not-outlier
# 803     not-outlier
# 804     not-outlier
# 805     not-outlier
# 806     not-outlier
# 807     not-outlier
# 808     not-outlier
# 809     not-outlier
# 810     not-outlier
# 811     not-outlier
# 812     not-outlier
# 813     not-outlier
# 814     not-outlier
# 815     not-outlier
# 816     not-outlier
# 817     not-outlier
# 818     not-outlier
# 819     not-outlier
# 820     not-outlier
# 821     not-outlier
# 822     not-outlier
# 823     not-outlier
# 824     not-outlier
# 825     not-outlier
# 826     not-outlier
# 827     not-outlier
# 828     not-outlier
# 829     not-outlier
# 830     not-outlier
# 831     not-outlier
# 832     not-outlier
# 833     not-outlier
# 834     not-outlier
# 835     not-outlier
# 836     not-outlier
# 837     not-outlier
# 838     not-outlier
# 839     not-outlier
# 840     not-outlier
# 841     not-outlier
# 842     not-outlier
# 843     not-outlier
# 844     not-outlier
# 845     not-outlier
# 846     not-outlier
# 847     not-outlier
# 848     not-outlier
# 849     not-outlier
# 850     not-outlier
# 851     not-outlier
# 852     not-outlier
# 853     not-outlier
# 854     not-outlier
# 855     not-outlier
# 856     not-outlier
# 857     not-outlier
# 858     not-outlier
# 859     not-outlier
# 860     not-outlier
# 861     not-outlier
# 862     not-outlier
# 863     not-outlier
# 864     not-outlier
# 865     not-outlier
# 866     not-outlier
# 867     not-outlier
# 868     not-outlier
# 869     not-outlier
# 870     not-outlier
# 871     not-outlier
# 872     not-outlier
# 873     not-outlier
# 874     not-outlier
# 875     not-outlier
# 876     not-outlier
# 877     not-outlier
# 878     not-outlier
# 879     not-outlier
# 880     not-outlier
# 881     not-outlier
# 882     not-outlier
# 883     not-outlier
# 884     not-outlier
# 885     not-outlier
# 886     not-outlier
# 887     not-outlier
# 888     not-outlier
# 889     not-outlier
# 890     not-outlier
# 891     not-outlier
# 892     not-outlier
# 893     not-outlier
# 894     not-outlier
# 895     not-outlier
# 896     not-outlier
# 897     not-outlier
# 898     not-outlier
# 899     not-outlier
# 900     not-outlier
# 901     not-outlier
# 902     not-outlier
# 903     not-outlier
# 904     not-outlier
# 905     not-outlier
# 906     not-outlier
# 907     not-outlier
# 908     not-outlier
# 909     not-outlier
# 910     not-outlier
# 911     not-outlier
# 912     not-outlier
# 913     not-outlier
# 914     not-outlier
# 915     not-outlier
# 916     not-outlier
# 917     not-outlier
# 918     not-outlier
# 919     not-outlier
# 920     not-outlier
# 921     not-outlier
# 922     not-outlier
# 923     not-outlier
# 924     not-outlier
# 925     not-outlier
# 926     not-outlier
# 927     not-outlier
# 928     not-outlier
# 929     not-outlier
# 930     not-outlier
# 931     not-outlier
# 932     not-outlier
# 933     not-outlier
# 934     not-outlier
# 935     not-outlier
# 936     not-outlier
# 937     not-outlier
# 938     not-outlier
# 939     not-outlier
# 940     not-outlier
# 941     not-outlier
# 942         outlier
# 943     not-outlier
# 944     not-outlier
# 945     not-outlier
# 946     not-outlier
# 947     not-outlier
# 948     not-outlier
# 949     not-outlier
# 950     not-outlier
# 951     not-outlier
# 952     not-outlier
# 953     not-outlier
# 954     not-outlier
# 955     not-outlier
# 956     not-outlier
# 957     not-outlier
# 958     not-outlier
# 959     not-outlier
# 960     not-outlier
# 961     not-outlier
# 962     not-outlier
# 963     not-outlier
# 964     not-outlier
# 965     not-outlier
# 966     not-outlier
# 967     not-outlier
# 968     not-outlier
# 969     not-outlier
# 970     not-outlier
# 971     not-outlier
# 972     not-outlier
# 973     not-outlier
# 974     not-outlier
# 975     not-outlier
# 976     not-outlier
# 977     not-outlier
# 978     not-outlier
# 979     not-outlier
# 980     not-outlier
# 981     not-outlier
# 982     not-outlier
# 983     not-outlier
# 984     not-outlier
# 985     not-outlier
# 986     not-outlier
# 987     not-outlier
# 988     not-outlier
# 989     not-outlier
# 990     not-outlier
# 991     not-outlier
# 992     not-outlier
# 993     not-outlier
# 994     not-outlier
# 995     not-outlier
# 996     not-outlier
# 997     not-outlier
# 998     not-outlier
# 999     not-outlier
# 1000    not-outlier
# 1001    not-outlier
# 1002    not-outlier
# 1003    not-outlier
# 1004    not-outlier
# 1005    not-outlier
# 1006    not-outlier
# 1007    not-outlier
# 1008    not-outlier
# 1009    not-outlier
# 1010    not-outlier
# 1011    not-outlier
# 1012    not-outlier
# 1013    not-outlier
# 1014    not-outlier
# 1015    not-outlier
# 1016    not-outlier
# 1017    not-outlier
# 1018    not-outlier
# 1019    not-outlier
# 1020    not-outlier
# 1021    not-outlier
# 1022    not-outlier
# 1023    not-outlier
# 1024    not-outlier
# 1025    not-outlier
# 1026    not-outlier
# 1027    not-outlier
# 1028    not-outlier
# 1029    not-outlier
# 1030    not-outlier
# 1031    not-outlier
# 1032    not-outlier
# 1033    not-outlier
# 1034    not-outlier
# 1035    not-outlier
# 1036    not-outlier
# 1037    not-outlier
# 1038    not-outlier
# 1039    not-outlier
# 1040    not-outlier
# 1041    not-outlier
# 1042    not-outlier
# 1043    not-outlier
# 1044    not-outlier
# 1045    not-outlier
# 1046    not-outlier
# 1047    not-outlier
# 1048    not-outlier
# 1049    not-outlier
# 1050    not-outlier
# 1051    not-outlier
# 1052    not-outlier
# 1053    not-outlier
# 1054    not-outlier
# 1055    not-outlier
# 1056    not-outlier
# 1057    not-outlier
# 1058    not-outlier
# 1059    not-outlier
# 1060    not-outlier
# 1061    not-outlier
# 1062    not-outlier
# 1063    not-outlier
# 1064    not-outlier
# 1065    not-outlier
# 1066    not-outlier
# 1067    not-outlier
# 1068    not-outlier
# 1069    not-outlier
# 1070    not-outlier
# 1071    not-outlier
# 1072    not-outlier
# 1073    not-outlier
# 1074    not-outlier
# 1075    not-outlier
# 1076    not-outlier
# 1077    not-outlier
# 1078    not-outlier
# 1079    not-outlier
# 1080    not-outlier
# 1081    not-outlier
# 1082    not-outlier
# 1083    not-outlier
# 1084    not-outlier
# 1085    not-outlier
# 1086    not-outlier
# 1087    not-outlier
# 1088    not-outlier
# 1089    not-outlier
# 1090    not-outlier
# 1091    not-outlier
# 1092    not-outlier
# 1093    not-outlier
# 1094    not-outlier
# 1095    not-outlier
# 1096    not-outlier
# 1097    not-outlier
# 1098    not-outlier
# 1099    not-outlier
# 1100    not-outlier
# 1101    not-outlier
# 1102    not-outlier
# 1103    not-outlier
# 1104    not-outlier
# 1105    not-outlier
# 1106    not-outlier
# 1107    not-outlier
# 1108    not-outlier
# 1109    not-outlier
# 1110    not-outlier
# 1111    not-outlier
# 1112    not-outlier
# 1113    not-outlier
# 1114    not-outlier
# 1115    not-outlier
# 1116    not-outlier
# 1117    not-outlier
# 1118    not-outlier
# 1119    not-outlier
# 1120    not-outlier
# 1121    not-outlier
# 1122    not-outlier
# 1123    not-outlier
# 1124    not-outlier
# 1125    not-outlier
# 1126    not-outlier
# 1127    not-outlier
# 1128    not-outlier
# 1129    not-outlier
# 1130    not-outlier
# 1131    not-outlier
# 1132    not-outlier
# 1133    not-outlier
# 1134    not-outlier
# 1135    not-outlier
# 1136    not-outlier
# 1137    not-outlier
# 1138    not-outlier
# 1139    not-outlier
# 1140    not-outlier
# 1141    not-outlier
# 1142    not-outlier
# 1143    not-outlier
# 1144    not-outlier
# 1145    not-outlier
# 1146    not-outlier
# 1147    not-outlier
# 1148    not-outlier
# 1149    not-outlier
# 1150    not-outlier
# 1151    not-outlier
# 1152    not-outlier
# 1153    not-outlier
# 1154    not-outlier
# 1155    not-outlier
# 1156    not-outlier
# 1157    not-outlier
# 1158    not-outlier
# 1159    not-outlier
# 1160    not-outlier
# 1161    not-outlier
# 1162    not-outlier
# 1163    not-outlier
# 1164    not-outlier
# 1165    not-outlier
# 1166    not-outlier
# 1167    not-outlier
# 1168    not-outlier
# 1169    not-outlier
# 1170    not-outlier
# 1171    not-outlier
# 1172    not-outlier
# 1173    not-outlier
# 1174    not-outlier
# 1175    not-outlier
# 1176    not-outlier
# 1177    not-outlier
# 1178    not-outlier
# 1179    not-outlier
# 1180    not-outlier
# 1181    not-outlier
# 1182    not-outlier
# 1183    not-outlier
# 1184    not-outlier
# 1185    not-outlier
# 1186    not-outlier
# 1187    not-outlier
# 1188    not-outlier
# 1189    not-outlier
# 1190    not-outlier
# 1191    not-outlier
# 1192    not-outlier
# 1193        outlier
# 1194    not-outlier
# 1195    not-outlier
# 1196    not-outlier
# 1197    not-outlier
# 1198    not-outlier
# 1199    not-outlier
# 1200    not-outlier
# 1201    not-outlier
# 1202    not-outlier
# 1203    not-outlier
# 1204    not-outlier
# 1205    not-outlier
# 1206    not-outlier
# 1207    not-outlier
# 1208    not-outlier
# 1209    not-outlier
# 1210    not-outlier
# 1211    not-outlier
# 1212    not-outlier
# 1213    not-outlier
# 1214    not-outlier
# 1215    not-outlier
# 1216    not-outlier
# 1217    not-outlier
# 1218    not-outlier
# 1219    not-outlier
# 1220    not-outlier
# 1221    not-outlier
# 1222    not-outlier
# 1223    not-outlier
# 1224    not-outlier
# 1225    not-outlier
# 1226    not-outlier
# 1227    not-outlier
# 1228    not-outlier
# 1229    not-outlier
# 1230    not-outlier
# 1231    not-outlier
# 1232    not-outlier
# 1233    not-outlier
# 1234    not-outlier
# 1235    not-outlier
# 1236    not-outlier
# 1237    not-outlier
# 1238    not-outlier
# 1239    not-outlier
# 1240    not-outlier
# 1241    not-outlier
# 1242    not-outlier
# 1243    not-outlier
# 1244    not-outlier
# 1245    not-outlier
# 1246    not-outlier
# 1247    not-outlier
# 1248    not-outlier
# 1249    not-outlier
# 1250    not-outlier
# 1251    not-outlier
# 1252    not-outlier
# 1253    not-outlier
# 1254    not-outlier
# 1255    not-outlier
# 1256    not-outlier
# 1257    not-outlier
# 1258    not-outlier
# 1259    not-outlier
# 1260    not-outlier
# 1261    not-outlier
# 1262    not-outlier
# 1961    not-outlier
# 1962        outlier
# 1963    not-outlier
# 1964    not-outlier
# 1965    not-outlier
# 1966    not-outlier
# 1967    not-outlier
# 1968    not-outlier
# 1969    not-outlier
# 1970    not-outlier
# 1971    not-outlier
# 1972    not-outlier
# 1973    not-outlier
# 1974    not-outlier
# 1975    not-outlier
# 1976    not-outlier
# 1977    not-outlier
# 1978    not-outlier
# 1979    not-outlier
# 1980    not-outlier
# 1981    not-outlier
# 1982    not-outlier
# 1983    not-outlier
# 1984    not-outlier
# 1985    not-outlier
# 1986    not-outlier
# 1987    not-outlier
# 1988    not-outlier
# 1989    not-outlier
# 1990    not-outlier
# 1991    not-outlier
# 1992    not-outlier
# 1993    not-outlier
# 1994    not-outlier
# 1995    not-outlier
# 1996    not-outlier
# 1997    not-outlier
# 1998    not-outlier
# 1999    not-outlier
# 2000    not-outlier
# 2001    not-outlier
# 2002    not-outlier
# 2003    not-outlier
# 2004    not-outlier
# 2005    not-outlier
# 2006    not-outlier
# 2007    not-outlier
# 2008    not-outlier
# 2009    not-outlier
# 2010    not-outlier
# 2011    not-outlier
# 2012    not-outlier
# 2013    not-outlier
# 2014    not-outlier
# 2015    not-outlier
# 2016    not-outlier
# 2017    not-outlier
# 2018    not-outlier
# 2019    not-outlier
# 2020    not-outlier
# 2021    not-outlier
# 2022    not-outlier
# 2023    not-outlier
# 2024    not-outlier
# 2025    not-outlier
# 2026    not-outlier
# 2027    not-outlier
# 2028    not-outlier
# 2029    not-outlier
# 2030    not-outlier
# 2031    not-outlier
# 2032    not-outlier
# 2033    not-outlier
# 2034    not-outlier
# 2035    not-outlier
# 2036    not-outlier
# 2037    not-outlier
# 2038    not-outlier
# 2039    not-outlier
# 2040    not-outlier
# 2041    not-outlier
# 2042    not-outlier
# 2043    not-outlier
# 2044    not-outlier
# 2045    not-outlier
# 2046    not-outlier
# 2047    not-outlier
# 2048    not-outlier
# 2049    not-outlier
# 2050    not-outlier
# 2051    not-outlier
# 2052    not-outlier
# 2053    not-outlier
# 2054    not-outlier
# 2055    not-outlier
# 2056    not-outlier
# 2057    not-outlier
# 2058    not-outlier
# 2059    not-outlier
# 2060    not-outlier
# 2061    not-outlier
# 2062    not-outlier
# 2063    not-outlier
# 2064    not-outlier
# 2065    not-outlier
# 2066    not-outlier
# 2067    not-outlier
# 2068    not-outlier
# 2069    not-outlier
# 2070    not-outlier
# 2071    not-outlier
# 2072    not-outlier
# 2073    not-outlier
# 2074    not-outlier
# 2075    not-outlier
# 2076    not-outlier
# 2077    not-outlier
# 2078    not-outlier
# 2079    not-outlier
# 2080    not-outlier
# 2081    not-outlier
# 2082    not-outlier
# 2083    not-outlier
# 2084    not-outlier
# 2085    not-outlier
# 2086    not-outlier
# 2087    not-outlier
# 2088    not-outlier
# 2089    not-outlier
# 2090    not-outlier
# 2091    not-outlier
# 2092    not-outlier
# 2093    not-outlier
# 2094    not-outlier
# 2095    not-outlier
# 2096    not-outlier
# 2097    not-outlier
# 2098    not-outlier
# 2099    not-outlier
# 2100    not-outlier
# 2101    not-outlier
# 2102    not-outlier
# 2103    not-outlier
# 2104    not-outlier
# 2105    not-outlier
# 2106    not-outlier
# 2107    not-outlier
# 2108    not-outlier
# 2109    not-outlier
# 2110    not-outlier
# 2111    not-outlier
# 2112    not-outlier
# 2113    not-outlier
# 2114    not-outlier
# 2115    not-outlier
# 2116    not-outlier
# 2117    not-outlier
# 2118    not-outlier
# 2119    not-outlier
# 2120    not-outlier
# 2121    not-outlier
# 2122    not-outlier
# 2123    not-outlier
# 2124    not-outlier
# 2125    not-outlier
# 2126    not-outlier
# 2127    not-outlier
# 2128    not-outlier
# 2129    not-outlier
# 2130    not-outlier
# 2131    not-outlier
# 2132    not-outlier
# 2133    not-outlier
# 2134    not-outlier
# 2135    not-outlier
# 2136    not-outlier
# 2137    not-outlier
# 2138    not-outlier
# 2139    not-outlier
# 2140    not-outlier
# 2141    not-outlier
# 2142    not-outlier
# 2143    not-outlier
# 2144    not-outlier
# 2145    not-outlier
# 2146    not-outlier
# 2147    not-outlier
# 2148    not-outlier
# 2149    not-outlier
# 2150    not-outlier
# 2151    not-outlier
# 2152    not-outlier
# 2153    not-outlier
# 2154    not-outlier
# 2155    not-outlier
# 2156    not-outlier
# 2157    not-outlier
# 2158    not-outlier
# 2159    not-outlier
# 2160    not-outlier
# 2161    not-outlier
# 2162    not-outlier
# 2163    not-outlier
# 2164    not-outlier
# 2165    not-outlier
# 2166    not-outlier
# 2167    not-outlier
# 2168    not-outlier
# 2169    not-outlier
# 2170    not-outlier
# 2171    not-outlier
# 2172    not-outlier
# 2173    not-outlier
# 2174    not-outlier
# 2175    not-outlier
# 2176    not-outlier
# 2177    not-outlier
# 2178    not-outlier
# 2179    not-outlier
# 2180    not-outlier
# 2181    not-outlier
# 2182    not-outlier
# 2183    not-outlier
# 2184    not-outlier
# 2185    not-outlier
# 2186    not-outlier
# 2187    not-outlier
# 2188    not-outlier
# 2189    not-outlier
# 2190    not-outlier
# 2191    not-outlier
# 2192    not-outlier
# 2193    not-outlier
# 2194    not-outlier
# 2195    not-outlier
# 2196    not-outlier
# 2197    not-outlier
# 2198    not-outlier
# 2199    not-outlier
# 2200    not-outlier
# 2201    not-outlier
# 2202    not-outlier
# 2203    not-outlier
# 2204    not-outlier
# 2205    not-outlier
# 2206    not-outlier
# 2207    not-outlier
# 2208    not-outlier
# 2209    not-outlier
# 2210    not-outlier
# 2211    not-outlier
# 2212    not-outlier
# 2213    not-outlier
# 2214    not-outlier
# 2215    not-outlier
# 2216    not-outlier
# 2217    not-outlier
# 2218    not-outlier
# 2219    not-outlier
# 2220    not-outlier
# 2221    not-outlier
# 2222    not-outlier
# 2223    not-outlier
# 2224    not-outlier
# 2225    not-outlier
# 2226    not-outlier
# 2227    not-outlier
# 2228    not-outlier
# 2229    not-outlier
# 2230    not-outlier
# 2231    not-outlier
# 2232    not-outlier
# 2233    not-outlier
# 2234    not-outlier
# 2235    not-outlier
# 2236    not-outlier
# 2237    not-outlier
# 2238    not-outlier
# 2239    not-outlier
# 2240    not-outlier
# 2241    not-outlier
# 2242    not-outlier
# 2243    not-outlier
# 2244    not-outlier
# 2245    not-outlier
# 2246    not-outlier
# 2247    not-outlier
# 2248    not-outlier
# 2249    not-outlier
# 2250    not-outlier
# 2251    not-outlier
# 2252    not-outlier
# 2253    not-outlier
# 2254    not-outlier
# 2255    not-outlier
# 2256    not-outlier
# 2257    not-outlier
# 2258    not-outlier
# 2259    not-outlier
# 2260    not-outlier
# 2261    not-outlier
# 2262    not-outlier
# 2263    not-outlier
# 2264    not-outlier
# 2265    not-outlier
# 2266    not-outlier
# 2267    not-outlier
# 2268    not-outlier
# 2269    not-outlier
# 2270    not-outlier
# 2271    not-outlier
# 2272    not-outlier
# 2273    not-outlier
# 2274    not-outlier
# 2275    not-outlier
# 2276    not-outlier
# 2277    not-outlier
# 2278    not-outlier
# 2279    not-outlier
# 2280    not-outlier
# 2281    not-outlier
# 2282    not-outlier
# 2283    not-outlier
# 2284    not-outlier
# 2285    not-outlier
# 2286    not-outlier
# 2287    not-outlier
# 2288    not-outlier
# 2289    not-outlier
# 2290    not-outlier
# 2291    not-outlier
# 2292    not-outlier
# 2293    not-outlier
# 2294    not-outlier
# 2295    not-outlier
# 2296    not-outlier
# 2297    not-outlier
# 2298    not-outlier
# 2299    not-outlier
# 2300    not-outlier
# 2301    not-outlier
# 2302    not-outlier
# 2303    not-outlier
# 2304    not-outlier
# 2305    not-outlier
# 2306    not-outlier
# 2307    not-outlier
# 2308    not-outlier
# 2309    not-outlier
# 2310    not-outlier
# 2311    not-outlier
# 2312    not-outlier
# 2313    not-outlier
# 2314    not-outlier
# 2315    not-outlier
# 2316    not-outlier
# 2317    not-outlier
# 2318    not-outlier
# 2319    not-outlier
# 2320    not-outlier
# 2321    not-outlier
# 2322    not-outlier
# 2323    not-outlier
# 2324    not-outlier
# 2325    not-outlier
# 2326    not-outlier
# 2327    not-outlier
# 2328    not-outlier
# 2329    not-outlier
# 2330    not-outlier
# 2331    not-outlier
# 2332    not-outlier
# 2333    not-outlier
# 2334    not-outlier
# 2335    not-outlier
# 2336    not-outlier
# 2337    not-outlier
# 2338    not-outlier
# 2339    not-outlier
# 2340    not-outlier
# 2341    not-outlier
# 2342    not-outlier
# 2343    not-outlier
# 2344    not-outlier
# 2345    not-outlier
# 2346    not-outlier
# 2347    not-outlier
# 2348    not-outlier
# 2349    not-outlier
# 2350    not-outlier
# 2351    not-outlier
# 2352    not-outlier
# 2353    not-outlier
# 2354    not-outlier
# 2355    not-outlier
# 2356    not-outlier
# 2357    not-outlier
# 2358    not-outlier
# 2359    not-outlier
# 2360    not-outlier
# 2361    not-outlier
# 2362    not-outlier
# 2363    not-outlier
# 2364    not-outlier
# 2365    not-outlier
# 2366    not-outlier
# 2367    not-outlier
# 2368    not-outlier
# 2369    not-outlier
# 2370    not-outlier
# 2371    not-outlier
# 2372    not-outlier
# 2373    not-outlier
# 2374    not-outlier
# 2375    not-outlier
# 2376    not-outlier
# 2377    not-outlier
# 2378    not-outlier
# 2379    not-outlier
# 2380    not-outlier
# 2381    not-outlier
# 2382    not-outlier
# 2383    not-outlier
# 2384    not-outlier
# 2385    not-outlier
# 2386    not-outlier
# 2387    not-outlier
# 2388    not-outlier
# 2389    not-outlier
# 2390    not-outlier
# 2391    not-outlier
# 2392    not-outlier
# 2393    not-outlier
# 2394    not-outlier
# 2395    not-outlier
# 2396    not-outlier
# ...
# 9202    not-outlier
# 9203    not-outlier
# 9204    not-outlier
# 9205    not-outlier
# 9206    not-outlier
# 9207    not-outlier
# 9208    not-outlier
# 9209    not-outlier
# 9210        outlier
# 9211    not-outlier
# 9212    not-outlier
# 9213    not-outlier
# 9214    not-outlier
# 9215    not-outlier
# 9216    not-outlier
# 9217    not-outlier
# 9218    not-outlier
# 9219    not-outlier
# 9220    not-outlier
# 9221    not-outlier
# 9222    not-outlier
# 9223    not-outlier
# 9224    not-outlier
# 9225    not-outlier
# 9226    not-outlier
# 9227    not-outlier
# 9228    not-outlier
# 9229    not-outlier
# 9230    not-outlier
# 9231    not-outlier
# 9232    not-outlier
# 9233    not-outlier
# 9234    not-outlier
# 9235    not-outlier
# 9236    not-outlier
# 9237    not-outlier
# 9238    not-outlier
# 9239    not-outlier
# 9240    not-outlier
# 9241    not-outlier
# 9242    not-outlier
# 9243    not-outlier
# 9244    not-outlier
# 9245    not-outlier
# 9246    not-outlier
# 9247    not-outlier
# 9248    not-outlier
# 9249    not-outlier
# 9250    not-outlier
# 9251    not-outlier
# 9252    not-outlier
# 9253    not-outlier
# 9254    not-outlier
# 9255    not-outlier
# 9256    not-outlier
# 9257    not-outlier
# 9258    not-outlier
# 9259    not-outlier
# 9260    not-outlier
# 9261    not-outlier
# 9262    not-outlier
# 9263    not-outlier
# 9264    not-outlier
# 9265    not-outlier
# 9266    not-outlier
# 9267    not-outlier
# 9268    not-outlier
# 9269    not-outlier
# 9270    not-outlier
# 9271    not-outlier
# 9272    not-outlier
# 9273    not-outlier
# 9274    not-outlier
# 9275    not-outlier
# 9276    not-outlier
# 9277    not-outlier
# 9278    not-outlier
# 9279    not-outlier
# 9280    not-outlier
# 9281    not-outlier
# 9282    not-outlier
# 9283    not-outlier
# 9284    not-outlier
# 9285    not-outlier
# 9286    not-outlier
# 9287    not-outlier
# 9288    not-outlier
# 9289    not-outlier
# 9290    not-outlier
# 9291    not-outlier
# 9292    not-outlier
# 9293    not-outlier
# 9294    not-outlier
# 9295    not-outlier
# 9296    not-outlier
# 9297    not-outlier
# 9298    not-outlier
# 9299    not-outlier
# 9300    not-outlier
# 9301    not-outlier
# 9302    not-outlier
# 9303    not-outlier
# 9304    not-outlier
# 9305    not-outlier
# 9306    not-outlier
# 9307    not-outlier
# 9308    not-outlier
# 9309    not-outlier
# 9310    not-outlier
# 9311    not-outlier
# 9312    not-outlier
# 9313    not-outlier
# 9314    not-outlier
# 9315    not-outlier
# 9316    not-outlier
# 9317    not-outlier
# 9318    not-outlier
# 9319    not-outlier
# 9320    not-outlier
# 9321    not-outlier
# 9322    not-outlier
# 9323    not-outlier
# 9324    not-outlier
# 9604    not-outlier
# 9605    not-outlier
# 9606    not-outlier
# 9607    not-outlier
# 9608    not-outlier
# 9609    not-outlier
# 9610    not-outlier
# 9611    not-outlier
# 9612    not-outlier
# 9613    not-outlier
# 9614    not-outlier
# 9615    not-outlier
# 9616    not-outlier
# 9617    not-outlier
# 9618    not-outlier
# 9619    not-outlier
# 9620    not-outlier
# 9621    not-outlier
# 9622    not-outlier
# 9623    not-outlier
# 9624        outlier
# 9625    not-outlier
# 9626    not-outlier
# 9627    not-outlier
# 9628    not-outlier
# 9629    not-outlier
# 9630    not-outlier
# 9631    not-outlier
# 9632    not-outlier
# 9633    not-outlier
# 9634    not-outlier
# 9635    not-outlier
# 9636    not-outlier
# 9637    not-outlier
# 9638    not-outlier
# 9639    not-outlier
# 9640    not-outlier
# 9641    not-outlier
# 9642    not-outlier
# 9643    not-outlier
# 9644    not-outlier
# 9645    not-outlier
# 9646    not-outlier
# 9647    not-outlier
# 9648    not-outlier
# 9649    not-outlier
# 9650    not-outlier
# 9651    not-outlier
# 9652    not-outlier
# 9653    not-outlier
# 9654    not-outlier
# 9655    not-outlier
# 9656    not-outlier
# 9657    not-outlier
# 9658    not-outlier
# 9659    not-outlier
# 9660    not-outlier
# 9661    not-outlier
# 9662    not-outlier
# 9663    not-outlier
# 9664    not-outlier
# 9665    not-outlier
# 9666    not-outlier
# 9667    not-outlier
# 9668    not-outlier
# 9669    not-outlier
# 9670    not-outlier
# 9671    not-outlier
# 9672    not-outlier
# 9673    not-outlier
# 9674    not-outlier
# 9675    not-outlier
# 9676    not-outlier
# 9677    not-outlier
# 9678    not-outlier
# 9679    not-outlier
# 9680    not-outlier
# 9681    not-outlier
# 9682    not-outlier
# 9683    not-outlier
# 9684    not-outlier
# 9685    not-outlier
# 9686    not-outlier
# 9687    not-outlier
# 9688    not-outlier
# 9689    not-outlier
# 9690    not-outlier
# 9691    not-outlier
# 9692    not-outlier
# 9693    not-outlier
# 9694    not-outlier
# 9695    not-outlier
# 9696    not-outlier
# 9697    not-outlier
# 9698    not-outlier
# 9699    not-outlier
# 9700    not-outlier
# 9701    not-outlier
# 9702    not-outlier
# 9703    not-outlier
# 9704    not-outlier
# 9705    not-outlier
# 9706    not-outlier
# 9707    not-outlier
# 9708    not-outlier
# 9709    not-outlier
# 9710    not-outlier
# 9711    not-outlier
# 9712    not-outlier
# 9713    not-outlier
# 9714    not-outlier
# 9715    not-outlier
# 9716    not-outlier
# 9717    not-outlier
# 9718    not-outlier
# 9719    not-outlier
# 9720    not-outlier
# 9721    not-outlier
# 9722    not-outlier
# 9723    not-outlier
# 9724    not-outlier
# 9725    not-outlier
# 9726    not-outlier
# 9727    not-outlier
# 9728    not-outlier
# 9729    not-outlier
# 9730    not-outlier
# 9731    not-outlier
# 9732    not-outlier
# 9733    not-outlier
# 9734    not-outlier
# 9735    not-outlier
# 9736    not-outlier
# 9737    not-outlier
# 9738    not-outlier
# 9739    not-outlier
# 9740    not-outlier
# 9741    not-outlier
# 9742    not-outlier
# 9743    not-outlier
# 9884    not-outlier
# 9885    not-outlier
# 9886    not-outlier
# 9887    not-outlier
# 9888    not-outlier
# 9889    not-outlier
# 9890    not-outlier
# 9891    not-outlier
# 9892    not-outlier
# 9893    not-outlier
# 9894    not-outlier
# 9895    not-outlier
# 9896    not-outlier
# 9897    not-outlier
# 9898    not-outlier
# 9899    not-outlier
# 9900    not-outlier
# 9901    not-outlier
# 9902    not-outlier
# 9903    not-outlier
# 9904    not-outlier
# 9905    not-outlier
# 9906    not-outlier
# 9907    not-outlier
# 9908    not-outlier
# 9909    not-outlier
# 9910    not-outlier
# 9911    not-outlier
# 9912    not-outlier
# 9913    not-outlier
# 9914    not-outlier
# 9915    not-outlier
# 9916    not-outlier
# 9917    not-outlier
# 9918    not-outlier
# 9919    not-outlier
# 9920    not-outlier
# 9921    not-outlier
# 9922    not-outlier
# 9923    not-outlier
# 9924    not-outlier
# 9925    not-outlier
# 9926    not-outlier
# 9927    not-outlier
# 9928    not-outlier
# 9929    not-outlier
# 9930    not-outlier
# 9931    not-outlier
# 9932    not-outlier
# 9933    not-outlier
# 9934    not-outlier
# 9935    not-outlier
# 9936    not-outlier
# 9937    not-outlier
# 9938    not-outlier
# 9939    not-outlier
# 9940    not-outlier
# 9941    not-outlier
# 9942    not-outlier
# 9943    not-outlier
# 9944    not-outlier
# 9945    not-outlier
# 9946    not-outlier
# 9947    not-outlier
# 9948    not-outlier
# 9949    not-outlier
# 9950    not-outlier
# 9951    not-outlier
# 9952    not-outlier
# 9953    not-outlier
# 9954    not-outlier
# 9955    not-outlier
# 9956    not-outlier
# 9957    not-outlier
# 9958    not-outlier
# 9959    not-outlier
# 9960    not-outlier
# 9961    not-outlier
# 9962    not-outlier
# 9963    not-outlier
# 9964    not-outlier
# 9965    not-outlier
# 9966    not-outlier
# 9967    not-outlier
# 9968    not-outlier
# 9969    not-outlier
# 9970    not-outlier
# 9971    not-outlier
# 9972    not-outlier
# 9973    not-outlier
# 9974    not-outlier
# 9975    not-outlier
# 9976    not-outlier
# 9977    not-outlier
# 9978    not-outlier
# 9979    not-outlier
# 9980    not-outlier
# 9981    not-outlier
# 9982    not-outlier
# 9983    not-outlier
# 9984    not-outlier
# 9985    not-outlier
# 9986    not-outlier
# 9987    not-outlier
# 9988    not-outlier
# 9989    not-outlier
# 9990    not-outlier
# 9991    not-outlier
# 9992    not-outlier
# 9993    not-outlier
# 9994    not-outlier
# 9995    not-outlier
# 9996    not-outlier
# 9997    not-outlier
# 9998    not-outlier
# 9999    not-outlier
# Name: CreditScore, dtype: object

# %% [markdown]
# #### 2. Age vs Exited

# %%
hist_boxplot(data_new,'Age')

# %%
plot_num_category(data_new,'Age',TARGET)

# %%
anova(data_new,'Age',TARGET)
# Out:
# Conclusion: p-value 1.2399313093445346e-186 is less than alpha 0.05, ftest = 886.0632749090969
# There is a significant difference in the target based on the predictor.

# %%
dataOutlier(data_new, 'Age')
# Out:
# outlier lower limit: 14.0
# outlier upper limit: 62.0
# 0       not-outlier
# 1       not-outlier
# 2       not-outlier
# 3       not-outlier
# 4       not-outlier
# 5       not-outlier
# 6       not-outlier
# 7       not-outlier
# 8       not-outlier
# 9       not-outlier
# 10      not-outlier
# 11      not-outlier
# 12      not-outlier
# 13      not-outlier
# 14      not-outlier
# 15      not-outlier
# 16      not-outlier
# 17      not-outlier
# 18      not-outlier
# 19      not-outlier
# 20      not-outlier
# 21      not-outlier
# 22      not-outlier
# 23      not-outlier
# 24      not-outlier
# 25      not-outlier
# 26      not-outlier
# 27      not-outlier
# 28      not-outlier
# 29      not-outlier
# 30      not-outlier
# 31      not-outlier
# 32      not-outlier
# 33      not-outlier
# 34      not-outlier
# 35      not-outlier
# 36      not-outlier
# 37      not-outlier
# 38      not-outlier
# 39      not-outlier
# 40      not-outlier
# 41      not-outlier
# 42      not-outlier
# 43      not-outlier
# 44      not-outlier
# 45      not-outlier
# 46      not-outlier
# 47      not-outlier
# 48      not-outlier
# 49      not-outlier
# 50      not-outlier
# 51      not-outlier
# 52      not-outlier
# 53      not-outlier
# 54      not-outlier
# 55      not-outlier
# 56      not-outlier
# 57      not-outlier
# 58          outlier
# 59      not-outlier
# 60      not-outlier
# 61      not-outlier
# 62      not-outlier
# 63      not-outlier
# 64      not-outlier
# 65      not-outlier
# 66      not-outlier
# 67      not-outlier
# 68      not-outlier
# 69      not-outlier
# 70      not-outlier
# 71      not-outlier
# 72      not-outlier
# 73      not-outlier
# 74      not-outlier
# 75      not-outlier
# 76      not-outlier
# 77      not-outlier
# 78      not-outlier
# 79      not-outlier
# 80      not-outlier
# 81      not-outlier
# 82      not-outlier
# 83      not-outlier
# 84      not-outlier
# 85          outlier
# 86      not-outlier
# 87      not-outlier
# 88      not-outlier
# 89      not-outlier
# 90      not-outlier
# 91      not-outlier
# 92      not-outlier
# 93      not-outlier
# 94      not-outlier
# 95      not-outlier
# 96      not-outlier
# 97      not-outlier
# 98      not-outlier
# 99      not-outlier
# 100     not-outlier
# 101     not-outlier
# 102     not-outlier
# 103     not-outlier
# 104         outlier
# 105     not-outlier
# 106     not-outlier
# 107     not-outlier
# 108     not-outlier
# 109     not-outlier
# 110     not-outlier
# 111     not-outlier
# 112     not-outlier
# 113     not-outlier
# 114     not-outlier
# 115     not-outlier
# 116     not-outlier
# 117     not-outlier
# 118     not-outlier
# 119     not-outlier
# 120     not-outlier
# 121     not-outlier
# 122     not-outlier
# 123     not-outlier
# 124     not-outlier
# 125     not-outlier
# 126     not-outlier
# 127     not-outlier
# 128     not-outlier
# 129     not-outlier
# 130     not-outlier
# 131     not-outlier
# 132     not-outlier
# 133     not-outlier
# 134     not-outlier
# 135     not-outlier
# 136     not-outlier
# 137     not-outlier
# 138     not-outlier
# 139     not-outlier
# 140     not-outlier
# 141     not-outlier
# 142     not-outlier
# 143     not-outlier
# 144     not-outlier
# 145     not-outlier
# 146     not-outlier
# 147     not-outlier
# 148     not-outlier
# 149     not-outlier
# 150     not-outlier
# 151     not-outlier
# 152     not-outlier
# 153     not-outlier
# 154     not-outlier
# 155     not-outlier
# 156     not-outlier
# 157     not-outlier
# 158         outlier
# 159     not-outlier
# 160     not-outlier
# 161     not-outlier
# 162     not-outlier
# 163     not-outlier
# 164     not-outlier
# 165     not-outlier
# 166     not-outlier
# 167     not-outlier
# 168     not-outlier
# 169     not-outlier
# 170     not-outlier
# 171     not-outlier
# 172     not-outlier
# 173     not-outlier
# 174     not-outlier
# 175     not-outlier
# 176     not-outlier
# 177     not-outlier
# 178     not-outlier
# 179     not-outlier
# 180     not-outlier
# 181         outlier
# 182     not-outlier
# 183     not-outlier
# 184     not-outlier
# 185     not-outlier
# 186     not-outlier
# 187     not-outlier
# 188     not-outlier
# 189     not-outlier
# 190     not-outlier
# 191     not-outlier
# 192     not-outlier
# 193     not-outlier
# 194     not-outlier
# 195     not-outlier
# 196     not-outlier
# 197     not-outlier
# 198     not-outlier
# 199     not-outlier
# 200     not-outlier
# 201     not-outlier
# 202     not-outlier
# 203     not-outlier
# 204     not-outlier
# 205     not-outlier
# 206     not-outlier
# 207     not-outlier
# 208     not-outlier
# 209     not-outlier
# 210     not-outlier
# 211     not-outlier
# 212     not-outlier
# 213     not-outlier
# 214     not-outlier
# 215     not-outlier
# 216     not-outlier
# 217     not-outlier
# 218     not-outlier
# 219     not-outlier
# 220     not-outlier
# 221     not-outlier
# 222     not-outlier
# 223     not-outlier
# 224     not-outlier
# 225     not-outlier
# 226     not-outlier
# 227     not-outlier
# 228     not-outlier
# 229     not-outlier
# 230         outlier
# 231     not-outlier
# 232     not-outlier
# 233     not-outlier
# 234         outlier
# 235     not-outlier
# 236     not-outlier
# 237     not-outlier
# 238     not-outlier
# 239     not-outlier
# 240     not-outlier
# 241     not-outlier
# 242     not-outlier
# 243         outlier
# 244     not-outlier
# 245     not-outlier
# 246     not-outlier
# 247     not-outlier
# 248     not-outlier
# 249     not-outlier
# 250     not-outlier
# 251     not-outlier
# 252         outlier
# 253     not-outlier
# 254     not-outlier
# 255     not-outlier
# 256     not-outlier
# 257     not-outlier
# 258     not-outlier
# 259     not-outlier
# 260     not-outlier
# 261     not-outlier
# 262     not-outlier
# 263     not-outlier
# 264     not-outlier
# 265     not-outlier
# 266     not-outlier
# 267     not-outlier
# 268     not-outlier
# 269     not-outlier
# 270     not-outlier
# 271     not-outlier
# 272     not-outlier
# 273     not-outlier
# 274     not-outlier
# 275     not-outlier
# 276     not-outlier
# 277     not-outlier
# 278     not-outlier
# 279     not-outlier
# 280     not-outlier
# 281     not-outlier
# 282     not-outlier
# 283     not-outlier
# 284     not-outlier
# 285     not-outlier
# 286     not-outlier
# 287     not-outlier
# 288     not-outlier
# 289     not-outlier
# 290     not-outlier
# 291     not-outlier
# 292     not-outlier
# 293     not-outlier
# 294     not-outlier
# 295     not-outlier
# 296     not-outlier
# 297     not-outlier
# 298     not-outlier
# 299     not-outlier
# 300     not-outlier
# 301     not-outlier
# 302     not-outlier
# 303     not-outlier
# 304     not-outlier
# 305     not-outlier
# 306     not-outlier
# 307     not-outlier
# 308     not-outlier
# 309     not-outlier
# 310         outlier
# 311     not-outlier
# 312     not-outlier
# 313     not-outlier
# 314     not-outlier
# 315     not-outlier
# 316     not-outlier
# 317     not-outlier
# 318     not-outlier
# 319     not-outlier
# 320     not-outlier
# 321     not-outlier
# 322     not-outlier
# 323     not-outlier
# 324     not-outlier
# 325     not-outlier
# 326     not-outlier
# 327     not-outlier
# 328     not-outlier
# 329     not-outlier
# 330     not-outlier
# 331     not-outlier
# 332     not-outlier
# 333     not-outlier
# 334     not-outlier
# 335     not-outlier
# 336     not-outlier
# 337     not-outlier
# 338     not-outlier
# 339     not-outlier
# 340     not-outlier
# 341     not-outlier
# 342     not-outlier
# 343     not-outlier
# 344     not-outlier
# 345     not-outlier
# 346     not-outlier
# 347     not-outlier
# 348     not-outlier
# 349     not-outlier
# 350     not-outlier
# 351     not-outlier
# 352     not-outlier
# 353     not-outlier
# 354     not-outlier
# 355     not-outlier
# 356     not-outlier
# 357     not-outlier
# 358     not-outlier
# 359     not-outlier
# 360     not-outlier
# 361     not-outlier
# 362     not-outlier
# 363     not-outlier
# 364         outlier
# 365     not-outlier
# 366     not-outlier
# 367     not-outlier
# 368     not-outlier
# 369     not-outlier
# 370     not-outlier
# 371         outlier
# 372     not-outlier
# 373     not-outlier
# 374     not-outlier
# 375     not-outlier
# 376     not-outlier
# 377     not-outlier
# 378     not-outlier
# 379     not-outlier
# 380     not-outlier
# 381     not-outlier
# 382     not-outlier
# 383     not-outlier
# 384     not-outlier
# 385         outlier
# 386     not-outlier
# 387     not-outlier
# 388     not-outlier
# 389     not-outlier
# 390     not-outlier
# 391     not-outlier
# 392     not-outlier
# 393     not-outlier
# 394     not-outlier
# 395     not-outlier
# 396     not-outlier
# 397     not-outlier
# 398     not-outlier
# 399         outlier
# 400     not-outlier
# 401     not-outlier
# 402     not-outlier
# 403     not-outlier
# 404     not-outlier
# 405     not-outlier
# 406     not-outlier
# 407     not-outlier
# 408     not-outlier
# 409     not-outlier
# 410     not-outlier
# 411     not-outlier
# 412     not-outlier
# 413     not-outlier
# 414     not-outlier
# 415     not-outlier
# 416     not-outlier
# 417     not-outlier
# 418     not-outlier
# 419     not-outlier
# 420     not-outlier
# 421     not-outlier
# 422     not-outlier
# 423     not-outlier
# 424     not-outlier
# 425     not-outlier
# 426     not-outlier
# 427     not-outlier
# 428     not-outlier
# 429     not-outlier
# 430     not-outlier
# 431     not-outlier
# 432     not-outlier
# 433     not-outlier
# 434     not-outlier
# 435     not-outlier
# 436     not-outlier
# 437     not-outlier
# 438     not-outlier
# 439     not-outlier
# 440     not-outlier
# 441     not-outlier
# 442     not-outlier
# 443     not-outlier
# 444     not-outlier
# 445     not-outlier
# 446     not-outlier
# 447     not-outlier
# 448     not-outlier
# 449     not-outlier
# 450     not-outlier
# 451     not-outlier
# 452     not-outlier
# 453     not-outlier
# 454     not-outlier
# 455     not-outlier
# 456     not-outlier
# 457     not-outlier
# 458     not-outlier
# 459     not-outlier
# 460     not-outlier
# 461     not-outlier
# 462     not-outlier
# 463     not-outlier
# 464     not-outlier
# 465     not-outlier
# 466     not-outlier
# 467     not-outlier
# 468     not-outlier
# 469     not-outlier
# 470     not-outlier
# 471     not-outlier
# 472     not-outlier
# 473     not-outlier
# 474     not-outlier
# 475     not-outlier
# 476     not-outlier
# 477     not-outlier
# 478     not-outlier
# 479     not-outlier
# 480     not-outlier
# 481     not-outlier
# 482     not-outlier
# 483     not-outlier
# 484     not-outlier
# 485     not-outlier
# 486     not-outlier
# 487     not-outlier
# 488     not-outlier
# 489     not-outlier
# 490     not-outlier
# 491     not-outlier
# 492     not-outlier
# 493     not-outlier
# 494     not-outlier
# 495     not-outlier
# 496     not-outlier
# 497     not-outlier
# 498     not-outlier
# 499     not-outlier
# 500     not-outlier
# 501     not-outlier
# 502     not-outlier
# 503     not-outlier
# 504     not-outlier
# 505     not-outlier
# 506     not-outlier
# 507     not-outlier
# 508     not-outlier
# 509     not-outlier
# 510     not-outlier
# 511     not-outlier
# 512     not-outlier
# 513     not-outlier
# 514     not-outlier
# 515     not-outlier
# 516     not-outlier
# 517     not-outlier
# 518     not-outlier
# 519     not-outlier
# 520     not-outlier
# 521     not-outlier
# 522     not-outlier
# 523     not-outlier
# 524     not-outlier
# 525     not-outlier
# 526     not-outlier
# 527     not-outlier
# 528     not-outlier
# 529     not-outlier
# 530     not-outlier
# 531     not-outlier
# 532     not-outlier
# 533     not-outlier
# 534     not-outlier
# 535     not-outlier
# 536     not-outlier
# 537     not-outlier
# 538     not-outlier
# 539     not-outlier
# 540     not-outlier
# 541     not-outlier
# 542     not-outlier
# 543     not-outlier
# 544     not-outlier
# 545     not-outlier
# 546     not-outlier
# 547     not-outlier
# 548     not-outlier
# 549     not-outlier
# 550     not-outlier
# 551     not-outlier
# 552     not-outlier
# 553     not-outlier
# 554     not-outlier
# 555     not-outlier
# 556     not-outlier
# 557     not-outlier
# 558     not-outlier
# 559         outlier
# 560     not-outlier
# 561     not-outlier
# 562     not-outlier
# 563     not-outlier
# 564     not-outlier
# 565     not-outlier
# 566     not-outlier
# 567         outlier
# 568     not-outlier
# 569     not-outlier
# 570     not-outlier
# 571     not-outlier
# 572     not-outlier
# 573     not-outlier
# 574     not-outlier
# 575     not-outlier
# 576     not-outlier
# 577     not-outlier
# 578     not-outlier
# 579     not-outlier
# 580     not-outlier
# 581     not-outlier
# 582     not-outlier
# 583     not-outlier
# 584     not-outlier
# 585     not-outlier
# 586     not-outlier
# 587     not-outlier
# 588     not-outlier
# 589     not-outlier
# 590     not-outlier
# 591     not-outlier
# 592     not-outlier
# 593     not-outlier
# 594     not-outlier
# 595     not-outlier
# 596     not-outlier
# 597     not-outlier
# 598     not-outlier
# 599     not-outlier
# 600     not-outlier
# 601     not-outlier
# 602         outlier
# 603     not-outlier
# 604     not-outlier
# 605     not-outlier
# 606     not-outlier
# 607     not-outlier
# 608     not-outlier
# 609     not-outlier
# 610     not-outlier
# 611     not-outlier
# 612         outlier
# 613     not-outlier
# 614     not-outlier
# 615     not-outlier
# 616     not-outlier
# 617     not-outlier
# 618     not-outlier
# 619     not-outlier
# 620     not-outlier
# 621     not-outlier
# 622     not-outlier
# 623     not-outlier
# 624     not-outlier
# 625     not-outlier
# 626     not-outlier
# 627     not-outlier
# 628     not-outlier
# 629     not-outlier
# 630     not-outlier
# 631     not-outlier
# 632     not-outlier
# 633     not-outlier
# 634     not-outlier
# 635     not-outlier
# 636     not-outlier
# 637     not-outlier
# 638     not-outlier
# 639     not-outlier
# 640     not-outlier
# 641     not-outlier
# 642     not-outlier
# 643     not-outlier
# 644     not-outlier
# 645     not-outlier
# 646     not-outlier
# 647     not-outlier
# 648     not-outlier
# 649     not-outlier
# 650     not-outlier
# 651     not-outlier
# 652     not-outlier
# 653     not-outlier
# 654     not-outlier
# 655     not-outlier
# 656     not-outlier
# 657     not-outlier
# 658         outlier
# 659     not-outlier
# 660     not-outlier
# 661     not-outlier
# 662     not-outlier
# 663     not-outlier
# 664     not-outlier
# 665     not-outlier
# 666     not-outlier
# 667     not-outlier
# 668     not-outlier
# 669     not-outlier
# 670     not-outlier
# 671     not-outlier
# 672     not-outlier
# 673     not-outlier
# 674     not-outlier
# 675     not-outlier
# 676     not-outlier
# 677     not-outlier
# 678         outlier
# 679     not-outlier
# 680     not-outlier
# 681     not-outlier
# 682     not-outlier
# 683     not-outlier
# 684     not-outlier
# 685     not-outlier
# 686     not-outlier
# 687     not-outlier
# 688     not-outlier
# 689     not-outlier
# 690     not-outlier
# 691     not-outlier
# 692     not-outlier
# 693     not-outlier
# 694     not-outlier
# 695     not-outlier
# 696     not-outlier
# 697     not-outlier
# 698     not-outlier
# 699     not-outlier
# 700     not-outlier
# 701     not-outlier
# 702     not-outlier
# 703     not-outlier
# 704     not-outlier
# 705     not-outlier
# 706     not-outlier
# 707     not-outlier
# 708     not-outlier
# 709     not-outlier
# 710     not-outlier
# 711     not-outlier
# 712     not-outlier
# 713     not-outlier
# 714     not-outlier
# 715     not-outlier
# 716     not-outlier
# 717     not-outlier
# 718     not-outlier
# 719     not-outlier
# 720     not-outlier
# 721     not-outlier
# 722     not-outlier
# 723     not-outlier
# 724     not-outlier
# 725     not-outlier
# 726     not-outlier
# 727     not-outlier
# 728     not-outlier
# 729     not-outlier
# 730     not-outlier
# 731     not-outlier
# 732     not-outlier
# 733     not-outlier
# 734     not-outlier
# 735     not-outlier
# 736         outlier
# 737     not-outlier
# 738     not-outlier
# 739     not-outlier
# 740     not-outlier
# 741     not-outlier
# 742     not-outlier
# 743     not-outlier
# 744     not-outlier
# 745     not-outlier
# 746     not-outlier
# 747     not-outlier
# 748     not-outlier
# 749     not-outlier
# 750     not-outlier
# 751     not-outlier
# 752     not-outlier
# 753     not-outlier
# 754     not-outlier
# 755     not-outlier
# 756     not-outlier
# 757     not-outlier
# 758     not-outlier
# 759     not-outlier
# 760     not-outlier
# 761     not-outlier
# 762     not-outlier
# 763     not-outlier
# 764     not-outlier
# 765     not-outlier
# 766         outlier
# 767     not-outlier
# 768     not-outlier
# 769         outlier
# 770     not-outlier
# 771     not-outlier
# 772     not-outlier
# 773     not-outlier
# 774     not-outlier
# 775     not-outlier
# 776     not-outlier
# 777     not-outlier
# 778     not-outlier
# 779     not-outlier
# 780     not-outlier
# 781     not-outlier
# 782     not-outlier
# 783     not-outlier
# 784     not-outlier
# 785     not-outlier
# 786     not-outlier
# 787     not-outlier
# 788     not-outlier
# 789     not-outlier
# 790     not-outlier
# 791     not-outlier
# 792     not-outlier
# 793     not-outlier
# 794     not-outlier
# 795     not-outlier
# 796     not-outlier
# 797     not-outlier
# 798     not-outlier
# 799     not-outlier
# 800     not-outlier
# 801     not-outlier
# 802     not-outlier
# 803     not-outlier
# 804     not-outlier
# 805     not-outlier
# 806     not-outlier
# 807         outlier
# 808     not-outlier
# 809     not-outlier
# 810     not-outlier
# 811         outlier
# 812     not-outlier
# 813     not-outlier
# 814     not-outlier
# 815     not-outlier
# 816     not-outlier
# 817     not-outlier
# 818     not-outlier
# 819     not-outlier
# 820     not-outlier
# 821     not-outlier
# 822     not-outlier
# 823         outlier
# 824     not-outlier
# 825     not-outlier
# 826     not-outlier
# 827     not-outlier
# 828     not-outlier
# 829     not-outlier
# 830     not-outlier
# 831     not-outlier
# 832     not-outlier
# 833     not-outlier
# 834     not-outlier
# 835     not-outlier
# 836     not-outlier
# 837     not-outlier
# 838     not-outlier
# 839     not-outlier
# 840     not-outlier
# 841     not-outlier
# 842     not-outlier
# 843     not-outlier
# 844     not-outlier
# 845     not-outlier
# 846     not-outlier
# 847     not-outlier
# 848     not-outlier
# 849     not-outlier
# 850     not-outlier
# 851     not-outlier
# 852     not-outlier
# 853     not-outlier
# 854     not-outlier
# 855     not-outlier
# 856     not-outlier
# 857     not-outlier
# 858     not-outlier
# 859         outlier
# 860     not-outlier
# 861     not-outlier
# 862     not-outlier
# 863     not-outlier
# 864     not-outlier
# 865     not-outlier
# 866     not-outlier
# 867     not-outlier
# 868     not-outlier
# 869     not-outlier
# 870     not-outlier
# 871     not-outlier
# 872     not-outlier
# 873     not-outlier
# 874     not-outlier
# 875     not-outlier
# 876     not-outlier
# 877     not-outlier
# 878     not-outlier
# 879     not-outlier
# 880     not-outlier
# 881     not-outlier
# 882     not-outlier
# 883     not-outlier
# 884         outlier
# 885     not-outlier
# 886     not-outlier
# 887     not-outlier
# 888         outlier
# 889     not-outlier
# 890     not-outlier
# 891     not-outlier
# 892     not-outlier
# 893     not-outlier
# 894     not-outlier
# 895     not-outlier
# 896     not-outlier
# 897     not-outlier
# 898     not-outlier
# 899     not-outlier
# 900     not-outlier
# 901     not-outlier
# 902     not-outlier
# 903     not-outlier
# 904     not-outlier
# 905     not-outlier
# 906     not-outlier
# 907     not-outlier
# 908     not-outlier
# 909     not-outlier
# 910     not-outlier
# 911     not-outlier
# 912     not-outlier
# 913     not-outlier
# 914     not-outlier
# 915     not-outlier
# 916     not-outlier
# 917     not-outlier
# 918     not-outlier
# 919     not-outlier
# 920     not-outlier
# 921     not-outlier
# 922     not-outlier
# 923     not-outlier
# 924     not-outlier
# 925     not-outlier
# 926     not-outlier
# 927     not-outlier
# 928     not-outlier
# 929     not-outlier
# 930     not-outlier
# 931     not-outlier
# 932     not-outlier
# 933     not-outlier
# 934     not-outlier
# 935     not-outlier
# 936     not-outlier
# 937     not-outlier
# 938     not-outlier
# 939     not-outlier
# 940     not-outlier
# 941     not-outlier
# 942     not-outlier
# 943     not-outlier
# 944     not-outlier
# 945     not-outlier
# 946     not-outlier
# 947     not-outlier
# 948         outlier
# 949     not-outlier
# 950     not-outlier
# 951     not-outlier
# 952         outlier
# 953     not-outlier
# 954     not-outlier
# 955     not-outlier
# 956     not-outlier
# 957         outlier
# 958     not-outlier
# 959     not-outlier
# 960     not-outlier
# 961     not-outlier
# 962     not-outlier
# 963         outlier
# 964     not-outlier
# 965     not-outlier
# 966     not-outlier
# 967     not-outlier
# 968     not-outlier
# 969         outlier
# 970     not-outlier
# 971     not-outlier
# 972     not-outlier
# 973     not-outlier
# 974     not-outlier
# 975     not-outlier
# 976     not-outlier
# 977     not-outlier
# 978     not-outlier
# 979     not-outlier
# 980     not-outlier
# 981     not-outlier
# 982     not-outlier
# 983     not-outlier
# 984     not-outlier
# 985     not-outlier
# 986     not-outlier
# 987     not-outlier
# 988     not-outlier
# 989     not-outlier
# 990     not-outlier
# 991     not-outlier
# 992     not-outlier
# 993     not-outlier
# 994     not-outlier
# 995     not-outlier
# 996     not-outlier
# 997     not-outlier
# 998     not-outlier
# 999     not-outlier
# 1000    not-outlier
# 1001    not-outlier
# 1002    not-outlier
# 1003    not-outlier
# 1004    not-outlier
# 1005    not-outlier
# 1006    not-outlier
# 1007    not-outlier
# 1008    not-outlier
# 1009        outlier
# 1010    not-outlier
# 1011    not-outlier
# 1012    not-outlier
# 1013    not-outlier
# 1014    not-outlier
# 1015    not-outlier
# 1016    not-outlier
# 1017    not-outlier
# 1018    not-outlier
# 1019    not-outlier
# 1020    not-outlier
# 1021    not-outlier
# 1022    not-outlier
# 1023    not-outlier
# 1024    not-outlier
# 1025    not-outlier
# 1026    not-outlier
# 1027    not-outlier
# 1028    not-outlier
# 1029    not-outlier
# 1030    not-outlier
# 1031    not-outlier
# 1032    not-outlier
# 1033    not-outlier
# 1034    not-outlier
# 1035    not-outlier
# 1036    not-outlier
# 1037    not-outlier
# 1038    not-outlier
# 1039        outlier
# 1040        outlier
# 1041    not-outlier
# 1042    not-outlier
# 1043    not-outlier
# 1044    not-outlier
# 1045    not-outlier
# 1046    not-outlier
# 1047    not-outlier
# 1048    not-outlier
# 1049    not-outlier
# 1050    not-outlier
# 1051    not-outlier
# 1052    not-outlier
# 1053    not-outlier
# 1054    not-outlier
# 1055        outlier
# 1056    not-outlier
# 1057    not-outlier
# 1058    not-outlier
# 1059    not-outlier
# 1060    not-outlier
# 1061    not-outlier
# 1062    not-outlier
# 1063    not-outlier
# 1064    not-outlier
# 1065    not-outlier
# 1066    not-outlier
# 1067    not-outlier
# 1068    not-outlier
# 1069    not-outlier
# 1070    not-outlier
# 1071    not-outlier
# 1072    not-outlier
# 1073    not-outlier
# 1074    not-outlier
# 1075    not-outlier
# 1076    not-outlier
# 1077    not-outlier
# 1078    not-outlier
# 1079    not-outlier
# 1080    not-outlier
# 1081    not-outlier
# 1082    not-outlier
# 1083    not-outlier
# 1084    not-outlier
# 1085    not-outlier
# 1086    not-outlier
# 1087    not-outlier
# 1088    not-outlier
# 1089    not-outlier
# 1090    not-outlier
# 1091    not-outlier
# 1092    not-outlier
# 1093    not-outlier
# 1094    not-outlier
# 1095    not-outlier
# 1096    not-outlier
# 1097    not-outlier
# 1098    not-outlier
# 1099    not-outlier
# 1100    not-outlier
# 1101    not-outlier
# 1102    not-outlier
# 1103    not-outlier
# 1104    not-outlier
# 1105    not-outlier
# 1106    not-outlier
# 1107    not-outlier
# 1108    not-outlier
# 1109    not-outlier
# 1110    not-outlier
# 1111    not-outlier
# 1112    not-outlier
# 1113    not-outlier
# 1114    not-outlier
# 1115    not-outlier
# 1116    not-outlier
# 1117    not-outlier
# 1118    not-outlier
# 1119    not-outlier
# 1120    not-outlier
# 1121    not-outlier
# 1122    not-outlier
# 1123    not-outlier
# 1124    not-outlier
# 1125    not-outlier
# 1126    not-outlier
# 1127    not-outlier
# 1128    not-outlier
# 1129    not-outlier
# 1130    not-outlier
# 1131    not-outlier
# 1132    not-outlier
# 1133    not-outlier
# 1134    not-outlier
# 1135    not-outlier
# 1136    not-outlier
# 1137    not-outlier
# 1138    not-outlier
# 1139    not-outlier
# 1140    not-outlier
# 1141    not-outlier
# 1142    not-outlier
# 1143    not-outlier
# 1144    not-outlier
# 1145    not-outlier
# 1146    not-outlier
# 1147    not-outlier
# 1148    not-outlier
# 1149    not-outlier
# 1150    not-outlier
# 1151    not-outlier
# 1152    not-outlier
# 1153    not-outlier
# 1154    not-outlier
# 1155    not-outlier
# 1156    not-outlier
# 1157    not-outlier
# 1158    not-outlier
# 1159    not-outlier
# 1160    not-outlier
# 1161    not-outlier
# 1162    not-outlier
# 1163    not-outlier
# 1164    not-outlier
# 1165    not-outlier
# 1166    not-outlier
# 1167    not-outlier
# 1168    not-outlier
# 1169    not-outlier
# 1170    not-outlier
# 1171    not-outlier
# 1172    not-outlier
# 1173    not-outlier
# 1174    not-outlier
# 1175    not-outlier
# 1176    not-outlier
# 1177    not-outlier
# 1178    not-outlier
# 1179    not-outlier
# 1180    not-outlier
# 1181    not-outlier
# 1182    not-outlier
# 1183    not-outlier
# 1184    not-outlier
# 1185    not-outlier
# 1186    not-outlier
# 1187    not-outlier
# 1188    not-outlier
# 1189    not-outlier
# 1190    not-outlier
# 1191    not-outlier
# 1192    not-outlier
# 1193    not-outlier
# 1194    not-outlier
# 1195    not-outlier
# 1196    not-outlier
# 1197    not-outlier
# 1198    not-outlier
# 1199    not-outlier
# 1200    not-outlier
# 1201    not-outlier
# 1202    not-outlier
# 1203    not-outlier
# 1204    not-outlier
# 1205        outlier
# 1206    not-outlier
# 1207    not-outlier
# 1208    not-outlier
# 1209    not-outlier
# 1210    not-outlier
# 1211    not-outlier
# 1212    not-outlier
# 1213    not-outlier
# 1214    not-outlier
# 1215    not-outlier
# 1216    not-outlier
# 1217    not-outlier
# 1218    not-outlier
# 1219    not-outlier
# 1220    not-outlier
# 1221    not-outlier
# 1222    not-outlier
# 1223    not-outlier
# 1224    not-outlier
# 1225    not-outlier
# 1226    not-outlier
# 1227    not-outlier
# 1228    not-outlier
# 1229    not-outlier
# 1230    not-outlier
# 1231    not-outlier
# 1232    not-outlier
# 1233    not-outlier
# 1234        outlier
# 1235        outlier
# 1236    not-outlier
# 1237    not-outlier
# 1238    not-outlier
# 1239    not-outlier
# 1240    not-outlier
# 1241    not-outlier
# 1242    not-outlier
# 1243    not-outlier
# 1244    not-outlier
# 1245    not-outlier
# 1246        outlier
# 1247    not-outlier
# 1248    not-outlier
# 1249    not-outlier
# 1250    not-outlier
# 1251    not-outlier
# 1252        outlier
# 1253    not-outlier
# 1254    not-outlier
# 1255    not-outlier
# 1256    not-outlier
# 1257    not-outlier
# 1258    not-outlier
# 1259    not-outlier
# 1260    not-outlier
# 1261    not-outlier
# 1262    not-outlier
# 1263    not-outlier
# 1264    not-outlier
# 1265    not-outlier
# 1266    not-outlier
# 1267    not-outlier
# 1268    not-outlier
# 1269    not-outlier
# 1270    not-outlier
# 1271    not-outlier
# 1272    not-outlier
# 1273    not-outlier
# 1274    not-outlier
# 1275    not-outlier
# 1276    not-outlier
# 1277    not-outlier
# 1278        outlier
# 1279    not-outlier
# 1280    not-outlier
# 1281    not-outlier
# 1282    not-outlier
# 1283    not-outlier
# 1284    not-outlier
# 1285        outlier
# 1286    not-outlier
# 1287    not-outlier
# 1288    not-outlier
# 1289    not-outlier
# 1290    not-outlier
# 1291    not-outlier
# 1292    not-outlier
# 1293    not-outlier
# 1294    not-outlier
# 1295    not-outlier
# 1296    not-outlier
# 1297    not-outlier
# 1298    not-outlier
# 1299    not-outlier
# 1300    not-outlier
# 1301    not-outlier
# 1302    not-outlier
# 1303    not-outlier
# 1304    not-outlier
# 1305    not-outlier
# 1306    not-outlier
# 1307    not-outlier
# 1308    not-outlier
# 1309    not-outlier
# 1310    not-outlier
# 1311    not-outlier
# 1312    not-outlier
# 1313    not-outlier
# 1314    not-outlier
# 1315    not-outlier
# 1316    not-outlier
# 1317    not-outlier
# 1318    not-outlier
# 1319    not-outlier
# 1320    not-outlier
# 1321    not-outlier
# 1322    not-outlier
# 1323    not-outlier
# 1324    not-outlier
# 1325    not-outlier
# 1326    not-outlier
# 1327    not-outlier
# 1328    not-outlier
# 1329    not-outlier
# 1330    not-outlier
# 1331    not-outlier
# 1332    not-outlier
# 1333    not-outlier
# 1334    not-outlier
# 1335    not-outlier
# 1336    not-outlier
# 1337    not-outlier
# 1338    not-outlier
# 1339    not-outlier
# 1340    not-outlier
# 1341    not-outlier
# 1342        outlier
# 1343    not-outlier
# 1344    not-outlier
# 1345    not-outlier
# 1346    not-outlier
# 1347    not-outlier
# 1348    not-outlier
# 1349    not-outlier
# 1350    not-outlier
# 1351    not-outlier
# 1352    not-outlier
# 1353    not-outlier
# 1354    not-outlier
# 1355    not-outlier
# 1356    not-outlier
# 1357    not-outlier
# 1499    not-outlier
# 1500    not-outlier
# 1501    not-outlier
# 1502    not-outlier
# 1503    not-outlier
# 1504    not-outlier
# 1505    not-outlier
# 1506    not-outlier
# 1507    not-outlier
# 1508    not-outlier
# 1509    not-outlier
# 1510    not-outlier
# 1511    not-outlier
# 1512    not-outlier
# 1513    not-outlier
# 1514    not-outlier
# 1515    not-outlier
# 1516    not-outlier
# 1517    not-outlier
# 1518    not-outlier
# 1519        outlier
# 1520    not-outlier
# 1521    not-outlier
# 1522    not-outlier
# 1523    not-outlier
# 1524    not-outlier
# 1525    not-outlier
# 1526    not-outlier
# 1527    not-outlier
# 1528    not-outlier
# 1529    not-outlier
# 1530    not-outlier
# 1531    not-outlier
# 1532    not-outlier
# 1533    not-outlier
# 1534    not-outlier
# 1535    not-outlier
# 1536    not-outlier
# 1537    not-outlier
# 1538    not-outlier
# 1539    not-outlier
# 1540    not-outlier
# 1541    not-outlier
# 1542    not-outlier
# 1543        outlier
# 1544    not-outlier
# 1545    not-outlier
# 1546    not-outlier
# 1547    not-outlier
# 1548    not-outlier
# 1549    not-outlier
# 1550    not-outlier
# 1551    not-outlier
# 1552    not-outlier
# 1553    not-outlier
# 1554    not-outlier
# 1555    not-outlier
# 1556    not-outlier
# 1557    not-outlier
# 1558    not-outlier
# 1559    not-outlier
# 1560    not-outlier
# 1561    not-outlier
# 1562    not-outlier
# 1563    not-outlier
# 1564    not-outlier
# 1565    not-outlier
# 1566    not-outlier
# 1567    not-outlier
# 1568    not-outlier
# 1569    not-outlier
# 1570    not-outlier
# 1571    not-outlier
# 1572    not-outlier
# 1573    not-outlier
# 1574    not-outlier
# 1575    not-outlier
# 1576    not-outlier
# 1577    not-outlier
# 1578    not-outlier
# 1579    not-outlier
# 1580    not-outlier
# 1581    not-outlier
# 1582    not-outlier
# 1583    not-outlier
# 1584    not-outlier
# 1585    not-outlier
# 1586    not-outlier
# 1587    not-outlier
# 1588    not-outlier
# 1589    not-outlier
# 1590    not-outlier
# 1591    not-outlier
# 1592    not-outlier
# 1593    not-outlier
# 1594    not-outlier
# 1595    not-outlier
# 1596    not-outlier
# 1597    not-outlier
# 1598    not-outlier
# 1599    not-outlier
# 1600    not-outlier
# 1601    not-outlier
# 1602    not-outlier
# 1603    not-outlier
# 1604    not-outlier
# 1605    not-outlier
# 1606    not-outlier
# 1607        outlier
# 1608    not-outlier
# 1609    not-outlier
# 1610    not-outlier
# 1611    not-outlier
# 1612    not-outlier
# 1613    not-outlier
# 1614        outlier
# 1615    not-outlier
# 1616    not-outlier
# 1617    not-outlier
# 1618    not-outlier
# 1619    not-outlier
# 1620    not-outlier
# 1621    not-outlier
# 1622    not-outlier
# 1623    not-outlier
# 1624    not-outlier
# 1625    not-outlier
# 1626    not-outlier
# 1627    not-outlier
# 1628    not-outlier
# 1629    not-outlier
# 1630    not-outlier
# 1631    not-outlier
# 1632    not-outlier
# 1633    not-outlier
# 1634    not-outlier
# 1635    not-outlier
# 1636    not-outlier
# 1637    not-outlier
# 1638    not-outlier
# 1919    not-outlier
# 1920    not-outlier
# 1921    not-outlier
# 1922    not-outlier
# 1923    not-outlier
# 1924    not-outlier
# 1925    not-outlier
# 1926    not-outlier
# 1927    not-outlier
# 1928    not-outlier
# 1929    not-outlier
# 1930    not-outlier
# 1931    not-outlier
# 1932    not-outlier
# 1933        outlier
# 1934    not-outlier
# 1935    not-outlier
# 1936    not-outlier
# 1937    not-outlier
# 1938    not-outlier
# 1939    not-outlier
# 1940    not-outlier
# 1941    not-outlier
# 1942    not-outlier
# 1943    not-outlier
# 1944    not-outlier
# 1945    not-outlier
# 1946    not-outlier
# 1947    not-outlier
# 1948    not-outlier
# 1949    not-outlier
# 1950    not-outlier
# 1951    not-outlier
# 1952    not-outlier
# 1953    not-outlier
# 1954    not-outlier
# 1955    not-outlier
# 1956    not-outlier
# 1957    not-outlier
# 1958    not-outlier
# 1959    not-outlier
# 1960    not-outlier
# 1961    not-outlier
# 1962    not-outlier
# 1963    not-outlier
# 1964    not-outlier
# 1965    not-outlier
# 1966    not-outlier
# 1967    not-outlier
# 1968    not-outlier
# 1969    not-outlier
# 1970    not-outlier
# 1971    not-outlier
# 1972    not-outlier
# 1973    not-outlier
# 1974    not-outlier
# 1975    not-outlier
# 1976    not-outlier
# 1977    not-outlier
# 1978    not-outlier
# 1979    not-outlier
# 1980    not-outlier
# 1981        outlier
# 1982    not-outlier
# 1983    not-outlier
# 1984    not-outlier
# 1985    not-outlier
# 1986    not-outlier
# 1987    not-outlier
# 1988    not-outlier
# 1989    not-outlier
# 1990    not-outlier
# 1991    not-outlier
# 1992    not-outlier
# 1993    not-outlier
# 1994    not-outlier
# 1995    not-outlier
# 1996    not-outlier
# 1997    not-outlier
# 1998    not-outlier
# 1999    not-outlier
# 2000    not-outlier
# 2001    not-outlier
# 2002        outlier
# 2003    not-outlier
# 2004    not-outlier
# 2005    not-outlier
# 2006    not-outlier
# 2007    not-outlier
# 2008    not-outlier
# 2009    not-outlier
# 2010    not-outlier
# 2011    not-outlier
# 2012        outlier
# 2013    not-outlier
# 2014    not-outlier
# 2015    not-outlier
# 2016    not-outlier
# 2017    not-outlier
# 2018    not-outlier
# 2019    not-outlier
# 2020    not-outlier
# 2021    not-outlier
# 2022    not-outlier
# 2023    not-outlier
# 2024    not-outlier
# 2025    not-outlier
# 2026    not-outlier
# 2027    not-outlier
# 2028    not-outlier
# 2029    not-outlier
# 2030    not-outlier
# 2031    not-outlier
# 2032    not-outlier
# 2033    not-outlier
# 2034    not-outlier
# 2035    not-outlier
# 2036    not-outlier
# 2037    not-outlier
# 2038    not-outlier
# 2039        outlier
# 2040    not-outlier
# 2041    not-outlier
# 2042    not-outlier
# 2043    not-outlier
# 2044    not-outlier
# 2045    not-outlier
# 2046    not-outlier
# 2047    not-outlier
# 2048    not-outlier
# 2049    not-outlier
# 2050    not-outlier
# 2051    not-outlier
# 2052    not-outlier
# 2053        outlier
# 2054    not-outlier
# 2055    not-outlier
# 2056    not-outlier
# 2057    not-outlier
# 2058    not-outlier
# 2059    not-outlier
# 2060    not-outlier
# 2061    not-outlier
# 2062    not-outlier
# 2063    not-outlier
# 2064    not-outlier
# 2065    not-outlier
# 2066    not-outlier
# 2067    not-outlier
# 2068    not-outlier
# 2069    not-outlier
# 2070    not-outlier
# 2071    not-outlier
# 2072    not-outlier
# 2073    not-outlier
# 2074    not-outlier
# 2075    not-outlier
# 2076    not-outlier
# 2077    not-outlier
# 2078        outlier
# 2079    not-outlier
# 2080    not-outlier
# 2081    not-outlier
# 2082    not-outlier
# 2083    not-outlier
# 2084    not-outlier
# 2085    not-outlier
# 2086    not-outlier
# 2087    not-outlier
# 2088    not-outlier
# 2089    not-outlier
# 2090    not-outlier
# 2091    not-outlier
# 2092    not-outlier
# 2093    not-outlier
# 2094        outlier
# 2095    not-outlier
# 2096    not-outlier
# 2097    not-outlier
# 2098    not-outlier
# 2099    not-outlier
# 2100    not-outlier
# 2101    not-outlier
# 2102    not-outlier
# 2103    not-outlier
# 2104    not-outlier
# 2105    not-outlier
# 2106    not-outlier
# 2107    not-outlier
# 2108        outlier
# 2109    not-outlier
# 2110    not-outlier
# 2111    not-outlier
# 2112    not-outlier
# 2113    not-outlier
# 2114    not-outlier
# 2115    not-outlier
# 2116    not-outlier
# 2117    not-outlier
# 2118    not-outlier
# 2119    not-outlier
# 2120    not-outlier
# 2121    not-outlier
# 2122    not-outlier
# 2123    not-outlier
# 2124    not-outlier
# 2125    not-outlier
# 2126    not-outlier
# 2127    not-outlier
# 2128    not-outlier
# 2129    not-outlier
# 2130    not-outlier
# 2131    not-outlier
# 2132    not-outlier
# 2133    not-outlier
# 2134    not-outlier
# 2135    not-outlier
# 2136    not-outlier
# 2137    not-outlier
# 2138    not-outlier
# 2139    not-outlier
# 2140    not-outlier
# 2141    not-outlier
# 2142    not-outlier
# 2143    not-outlier
# 2144    not-outlier
# 2145    not-outlier
# 2146    not-outlier
# 2147    not-outlier
# 2148    not-outlier
# 2149    not-outlier
# 2150    not-outlier
# 2151    not-outlier
# 2152    not-outlier
# 2153    not-outlier
# 2154        outlier
# 2155    not-outlier
# 2156    not-outlier
# 2157    not-outlier
# 2158    not-outlier
# 2159        outlier
# 2160    not-outlier
# 2161    not-outlier
# 2162    not-outlier
# 2163    not-outlier
# 2164        outlier
# 2165    not-outlier
# 2166    not-outlier
# 2167    not-outlier
# 2168    not-outlier
# 2169    not-outlier
# 2170    not-outlier
# 2171    not-outlier
# 2172    not-outlier
# 2173    not-outlier
# 2174    not-outlier
# 2175    not-outlier
# 2176    not-outlier
# 2177    not-outlier
# 2178    not-outlier
# 2179    not-outlier
# 2180    not-outlier
# 2181    not-outlier
# 2182    not-outlier
# 2183    not-outlier
# 2184    not-outlier
# 2185    not-outlier
# 2186    not-outlier
# 2187    not-outlier
# 2188    not-outlier
# 2189    not-outlier
# 2190    not-outlier
# 2191    not-outlier
# 2192    not-outlier
# 2193    not-outlier
# 2194    not-outlier
# 2195    not-outlier
# 2196    not-outlier
# 2197    not-outlier
# 2198    not-outlier
# 2199    not-outlier
# 2200    not-outlier
# 2201    not-outlier
# 2202    not-outlier
# 2203    not-outlier
# 2204    not-outlier
# 2205    not-outlier
# 2206    not-outlier
# 2207    not-outlier
# 2208    not-outlier
# 2209    not-outlier
# 2210    not-outlier
# 2211    not-outlier
# 2212    not-outlier
# 2213    not-outlier
# 2214    not-outlier
# 2215    not-outlier
# 2216    not-outlier
# 2217    not-outlier
# 2218    not-outlier
# 2219    not-outlier
# 2220    not-outlier
# 2221    not-outlier
# 2222    not-outlier
# 2223    not-outlier
# 2224    not-outlier
# 2225    not-outlier
# 2226    not-outlier
# 2227    not-outlier
# 2228    not-outlier
# 2229    not-outlier
# 2230    not-outlier
# 2231    not-outlier
# 2232    not-outlier
# 2233    not-outlier
# 2234    not-outlier
# 2235    not-outlier
# 2236    not-outlier
# 2237    not-outlier
# 2238    not-outlier
# 2239    not-outlier
# 2240    not-outlier
# 2241    not-outlier
# 2242    not-outlier
# 2243    not-outlier
# 2244        outlier
# 2245    not-outlier
# 2246    not-outlier
# 2247    not-outlier
# 2248    not-outlier
# 2249    not-outlier
# 2250    not-outlier
# 2251    not-outlier
# 2252    not-outlier
# 2253    not-outlier
# 2254    not-outlier
# 2255    not-outlier
# 2256    not-outlier
# 2257    not-outlier
# 2258    not-outlier
# 2259    not-outlier
# 2260    not-outlier
# 2261    not-outlier
# 2262    not-outlier
# 2263    not-outlier
# 2264    not-outlier
# 2265    not-outlier
# 2266    not-outlier
# 2267    not-outlier
# 2268    not-outlier
# 2269    not-outlier
# 2270    not-outlier
# 2271    not-outlier
# 2272    not-outlier
# 2273    not-outlier
# 2274        outlier
# 2275    not-outlier
# 2276    not-outlier
# 2277    not-outlier
# 2278    not-outlier
# 2279    not-outlier
# 2280    not-outlier
# 2281    not-outlier
# 2282    not-outlier
# 2283    not-outlier
# 2284    not-outlier
# 2285    not-outlier
# 2286    not-outlier
# 2287    not-outlier
# 2288    not-outlier
# 2289    not-outlier
# 2290    not-outlier
# 2291    not-outlier
# 2292    not-outlier
# 2293    not-outlier
# 2294    not-outlier
# 2295    not-outlier
# 2296    not-outlier
# 2297    not-outlier
# 2298    not-outlier
# 2299    not-outlier
# 2300    not-outlier
# 2301    not-outlier
# 2302    not-outlier
# 2303    not-outlier
# 2304    not-outlier
# 2305    not-outlier
# 2306    not-outlier
# 2307    not-outlier
# 2308    not-outlier
# 2309    not-outlier
# 2310    not-outlier
# 2311    not-outlier
# 2312    not-outlier
# 2313    not-outlier
# 2314    not-outlier
# 2315    not-outlier
# 2316    not-outlier
# 2317    not-outlier
# 2318    not-outlier
# 2319    not-outlier
# 2320    not-outlier
# 2321    not-outlier
# 2322    not-outlier
# 2323    not-outlier
# 2324    not-outlier
# 2325    not-outlier
# 2326    not-outlier
# 2327    not-outlier
# 2328    not-outlier
# 2329    not-outlier
# 2330    not-outlier
# 2331    not-outlier
# 2332    not-outlier
# 2333    not-outlier
# 2334    not-outlier
# 2335    not-outlier
# 2336    not-outlier
# 2337    not-outlier
# 2338    not-outlier
# 2339    not-outlier
# 2340    not-outlier
# 2341    not-outlier
# 2342    not-outlier
# 2343    not-outlier
# 2344    not-outlier
# 2345    not-outlier
# 2346    not-outlier
# 2347    not-outlier
# 2348    not-outlier
# 2349    not-outlier
# 2350    not-outlier
# 2351    not-outlier
# 2352    not-outlier
# 2353    not-outlier
# 2354    not-outlier
# 2355    not-outlier
# 2356    not-outlier
# 2357    not-outlier
# 2358    not-outlier
# 2359    not-outlier
# 2360    not-outlier
# 2361    not-outlier
# 2362    not-outlier
# 2363    not-outlier
# 2364    not-outlier
# 2365    not-outlier
# 2366    not-outlier
# 2367    not-outlier
# 2368    not-outlier
# 2369    not-outlier
# 2370    not-outlier
# 2371    not-outlier
# 2372    not-outlier
# 2373    not-outlier
# 2374    not-outlier
# 2375    not-outlier
# 2376    not-outlier
# 2377    not-outlier
# 2378    not-outlier
# 2379    not-outlier
# 2380    not-outlier
# 2381    not-outlier
# 2382    not-outlier
# 2383    not-outlier
# 2384    not-outlier
# 2385    not-outlier
# 2386    not-outlier
# 2387    not-outlier
# 2388    not-outlier
# 2389    not-outlier
# 2390    not-outlier
# 2391    not-outlier
# 2392    not-outlier
# 2393    not-outlier
# 2394    not-outlier
# 2395    not-outlier
# 2396    not-outlier
# ...
# 9202    not-outlier
# 9203    not-outlier
# 9204    not-outlier
# 9205    not-outlier
# 9206    not-outlier
# 9207    not-outlier
# 9208    not-outlier
# 9209    not-outlier
# 9210    not-outlier
# 9211    not-outlier
# 9212    not-outlier
# 9213    not-outlier
# 9214    not-outlier
# 9215    not-outlier
# 9216    not-outlier
# 9217    not-outlier
# 9218    not-outlier
# 9219    not-outlier
# 9220    not-outlier
# 9221    not-outlier
# 9222    not-outlier
# 9223        outlier
# 9224    not-outlier
# 9225    not-outlier
# 9226    not-outlier
# 9227    not-outlier
# 9228    not-outlier
# 9229    not-outlier
# 9230    not-outlier
# 9231    not-outlier
# 9232    not-outlier
# 9233    not-outlier
# 9234    not-outlier
# 9235    not-outlier
# 9236    not-outlier
# 9237    not-outlier
# 9238    not-outlier
# 9239    not-outlier
# 9240    not-outlier
# 9241    not-outlier
# 9242    not-outlier
# 9243    not-outlier
# 9244    not-outlier
# 9245    not-outlier
# 9246    not-outlier
# 9247    not-outlier
# 9248    not-outlier
# 9249    not-outlier
# 9250    not-outlier
# 9251    not-outlier
# 9252    not-outlier
# 9253    not-outlier
# 9254    not-outlier
# 9255    not-outlier
# 9256    not-outlier
# 9257    not-outlier
# 9258    not-outlier
# 9259    not-outlier
# 9260    not-outlier
# 9261    not-outlier
# 9262    not-outlier
# 9263    not-outlier
# 9264    not-outlier
# 9265    not-outlier
# 9266    not-outlier
# 9267    not-outlier
# 9268    not-outlier
# 9269    not-outlier
# 9270    not-outlier
# 9271    not-outlier
# 9272    not-outlier
# 9273    not-outlier
# 9274    not-outlier
# 9275    not-outlier
# 9276    not-outlier
# 9277    not-outlier
# 9278    not-outlier
# 9279    not-outlier
# 9280    not-outlier
# 9281    not-outlier
# 9282    not-outlier
# 9283    not-outlier
# 9284    not-outlier
# 9285    not-outlier
# 9286    not-outlier
# 9287    not-outlier
# 9288    not-outlier
# 9289    not-outlier
# 9290    not-outlier
# 9291    not-outlier
# 9292        outlier
# 9293    not-outlier
# 9294    not-outlier
# 9295    not-outlier
# 9296    not-outlier
# 9297    not-outlier
# 9298    not-outlier
# 9299    not-outlier
# 9300    not-outlier
# 9301    not-outlier
# 9302    not-outlier
# 9303    not-outlier
# 9304    not-outlier
# 9305    not-outlier
# 9306    not-outlier
# 9307    not-outlier
# 9308    not-outlier
# 9309        outlier
# 9310    not-outlier
# 9311    not-outlier
# 9312    not-outlier
# 9313    not-outlier
# 9314    not-outlier
# 9315    not-outlier
# 9316    not-outlier
# 9317    not-outlier
# 9318        outlier
# 9319    not-outlier
# 9320    not-outlier
# 9321    not-outlier
# 9322    not-outlier
# 9323    not-outlier
# 9324        outlier
# 9325    not-outlier
# 9326    not-outlier
# 9327    not-outlier
# 9328    not-outlier
# 9329    not-outlier
# 9330    not-outlier
# 9331    not-outlier
# 9332    not-outlier
# 9333        outlier
# 9334    not-outlier
# 9335    not-outlier
# 9336    not-outlier
# 9337    not-outlier
# 9338    not-outlier
# 9339    not-outlier
# 9340    not-outlier
# 9341    not-outlier
# 9342    not-outlier
# 9343    not-outlier
# 9344    not-outlier
# 9345    not-outlier
# 9346    not-outlier
# 9347    not-outlier
# 9348    not-outlier
# 9349    not-outlier
# 9350    not-outlier
# 9351        outlier
# 9352    not-outlier
# 9353    not-outlier
# 9354    not-outlier
# 9355    not-outlier
# 9356    not-outlier
# 9357    not-outlier
# 9358    not-outlier
# 9359    not-outlier
# 9360    not-outlier
# 9361    not-outlier
# 9362    not-outlier
# 9363    not-outlier
# 9364    not-outlier
# 9365    not-outlier
# 9366    not-outlier
# 9367    not-outlier
# 9368    not-outlier
# 9369    not-outlier
# 9370    not-outlier
# 9371    not-outlier
# 9372    not-outlier
# 9373    not-outlier
# 9374    not-outlier
# 9375    not-outlier
# 9376    not-outlier
# 9377    not-outlier
# 9378    not-outlier
# 9379    not-outlier
# 9380        outlier
# 9381    not-outlier
# 9382    not-outlier
# 9383    not-outlier
# 9384    not-outlier
# 9385    not-outlier
# 9386    not-outlier
# 9387    not-outlier
# 9388    not-outlier
# 9389    not-outlier
# 9390    not-outlier
# 9391    not-outlier
# 9392    not-outlier
# 9393    not-outlier
# 9394    not-outlier
# 9395    not-outlier
# 9396    not-outlier
# 9397    not-outlier
# 9398    not-outlier
# 9399    not-outlier
# 9400    not-outlier
# 9401    not-outlier
# 9402        outlier
# 9403    not-outlier
# 9404    not-outlier
# 9405    not-outlier
# 9406    not-outlier
# 9407    not-outlier
# 9408    not-outlier
# 9409    not-outlier
# 9410    not-outlier
# 9411    not-outlier
# 9412    not-outlier
# 9413    not-outlier
# 9414    not-outlier
# 9415    not-outlier
# 9416    not-outlier
# 9417    not-outlier
# 9418    not-outlier
# 9419    not-outlier
# 9420    not-outlier
# 9421    not-outlier
# 9422    not-outlier
# 9423    not-outlier
# 9424    not-outlier
# 9425        outlier
# 9426    not-outlier
# 9427    not-outlier
# 9428        outlier
# 9429    not-outlier
# 9430    not-outlier
# 9431    not-outlier
# 9432    not-outlier
# 9433    not-outlier
# 9434    not-outlier
# 9435    not-outlier
# 9436    not-outlier
# 9437    not-outlier
# 9438        outlier
# 9439    not-outlier
# 9440    not-outlier
# 9441    not-outlier
# 9442    not-outlier
# 9443    not-outlier
# 9444    not-outlier
# 9445    not-outlier
# 9446    not-outlier
# 9447    not-outlier
# 9448    not-outlier
# 9449    not-outlier
# 9450    not-outlier
# 9451    not-outlier
# 9452    not-outlier
# 9453    not-outlier
# 9454    not-outlier
# 9455    not-outlier
# 9456    not-outlier
# 9457    not-outlier
# 9458    not-outlier
# 9459    not-outlier
# 9460    not-outlier
# 9461    not-outlier
# 9462    not-outlier
# 9463    not-outlier
# 9464    not-outlier
# 9465    not-outlier
# 9466    not-outlier
# 9467    not-outlier
# 9468    not-outlier
# 9469    not-outlier
# 9470    not-outlier
# 9471    not-outlier
# 9472        outlier
# 9473    not-outlier
# 9474    not-outlier
# 9475    not-outlier
# 9476    not-outlier
# 9477    not-outlier
# 9478    not-outlier
# 9479    not-outlier
# 9480    not-outlier
# 9481    not-outlier
# 9482    not-outlier
# 9483    not-outlier
# 9484    not-outlier
# 9485    not-outlier
# 9486    not-outlier
# 9487    not-outlier
# 9488    not-outlier
# 9489    not-outlier
# 9490        outlier
# 9491    not-outlier
# 9492    not-outlier
# 9493    not-outlier
# 9494    not-outlier
# 9495    not-outlier
# 9496    not-outlier
# 9497    not-outlier
# 9498    not-outlier
# 9499    not-outlier
# 9500    not-outlier
# 9501    not-outlier
# 9502    not-outlier
# 9503    not-outlier
# 9504    not-outlier
# 9505    not-outlier
# 9506        outlier
# 9507    not-outlier
# 9508    not-outlier
# 9509    not-outlier
# 9510    not-outlier
# 9511    not-outlier
# 9512    not-outlier
# 9513    not-outlier
# 9514    not-outlier
# 9515    not-outlier
# 9516    not-outlier
# 9517    not-outlier
# 9518    not-outlier
# 9519    not-outlier
# 9520    not-outlier
# 9521    not-outlier
# 9522    not-outlier
# 9523    not-outlier
# 9524    not-outlier
# 9525    not-outlier
# 9526    not-outlier
# 9527    not-outlier
# 9528    not-outlier
# 9529    not-outlier
# 9530    not-outlier
# 9531    not-outlier
# 9532    not-outlier
# 9533    not-outlier
# 9534    not-outlier
# 9535    not-outlier
# 9536    not-outlier
# 9537    not-outlier
# 9538    not-outlier
# 9539    not-outlier
# 9540    not-outlier
# 9541    not-outlier
# 9542    not-outlier
# 9543    not-outlier
# 9544    not-outlier
# 9545    not-outlier
# 9546    not-outlier
# 9547    not-outlier
# 9548    not-outlier
# 9549    not-outlier
# 9550    not-outlier
# 9551    not-outlier
# 9552    not-outlier
# 9553    not-outlier
# 9554    not-outlier
# 9555        outlier
# 9556    not-outlier
# 9557        outlier
# 9558    not-outlier
# 9559    not-outlier
# 9560    not-outlier
# 9561    not-outlier
# 9562    not-outlier
# 9563    not-outlier
# 9564    not-outlier
# 9565    not-outlier
# 9566    not-outlier
# 9567    not-outlier
# 9568    not-outlier
# 9569    not-outlier
# 9570    not-outlier
# 9571    not-outlier
# 9572    not-outlier
# 9573    not-outlier
# 9574    not-outlier
# 9575    not-outlier
# 9576    not-outlier
# 9577    not-outlier
# 9578    not-outlier
# 9579    not-outlier
# 9580    not-outlier
# 9581    not-outlier
# 9582    not-outlier
# 9583    not-outlier
# 9584    not-outlier
# 9585    not-outlier
# 9586    not-outlier
# 9587        outlier
# 9588    not-outlier
# 9589        outlier
# 9590    not-outlier
# 9591    not-outlier
# 9592    not-outlier
# 9593        outlier
# 9594    not-outlier
# 9595    not-outlier
# 9596    not-outlier
# 9597    not-outlier
# 9598    not-outlier
# 9599    not-outlier
# 9600    not-outlier
# 9601    not-outlier
# 9602    not-outlier
# 9603    not-outlier
# 9604    not-outlier
# 9605    not-outlier
# 9606    not-outlier
# 9607    not-outlier
# 9608    not-outlier
# 9609    not-outlier
# 9610    not-outlier
# 9611    not-outlier
# 9612    not-outlier
# 9613    not-outlier
# 9614    not-outlier
# 9615    not-outlier
# 9616    not-outlier
# 9617    not-outlier
# 9618    not-outlier
# 9619    not-outlier
# 9620    not-outlier
# 9621    not-outlier
# 9622    not-outlier
# 9623    not-outlier
# 9624    not-outlier
# 9625    not-outlier
# 9626    not-outlier
# 9627    not-outlier
# 9628    not-outlier
# 9629    not-outlier
# 9630    not-outlier
# 9631    not-outlier
# 9632    not-outlier
# 9633    not-outlier
# 9634    not-outlier
# 9635    not-outlier
# 9636    not-outlier
# 9637    not-outlier
# 9638    not-outlier
# 9639    not-outlier
# 9640    not-outlier
# 9641    not-outlier
# 9642    not-outlier
# 9643    not-outlier
# 9644    not-outlier
# 9645    not-outlier
# 9646        outlier
# 9647    not-outlier
# 9648    not-outlier
# 9649    not-outlier
# 9650    not-outlier
# 9651    not-outlier
# 9652    not-outlier
# 9653    not-outlier
# 9654    not-outlier
# 9655    not-outlier
# 9656    not-outlier
# 9657    not-outlier
# 9658    not-outlier
# 9659    not-outlier
# 9660    not-outlier
# 9661    not-outlier
# 9662    not-outlier
# 9663    not-outlier
# 9664    not-outlier
# 9665    not-outlier
# 9666    not-outlier
# 9667    not-outlier
# 9668    not-outlier
# 9669    not-outlier
# 9670    not-outlier
# 9671        outlier
# 9672    not-outlier
# 9673    not-outlier
# 9674    not-outlier
# 9675    not-outlier
# 9676    not-outlier
# 9677    not-outlier
# 9678    not-outlier
# 9679    not-outlier
# 9680    not-outlier
# 9681        outlier
# 9682    not-outlier
# 9683    not-outlier
# 9684    not-outlier
# 9685    not-outlier
# 9686        outlier
# 9687    not-outlier
# 9688        outlier
# 9689    not-outlier
# 9690    not-outlier
# 9691    not-outlier
# 9692    not-outlier
# 9693    not-outlier
# 9694    not-outlier
# 9695    not-outlier
# 9696    not-outlier
# 9697    not-outlier
# 9698    not-outlier
# 9699    not-outlier
# 9700    not-outlier
# 9701    not-outlier
# 9702    not-outlier
# 9703    not-outlier
# 9704    not-outlier
# 9705    not-outlier
# 9706    not-outlier
# 9707    not-outlier
# 9708    not-outlier
# 9709    not-outlier
# 9710    not-outlier
# 9711    not-outlier
# 9712    not-outlier
# 9713    not-outlier
# 9714    not-outlier
# 9715    not-outlier
# 9716    not-outlier
# 9717    not-outlier
# 9718    not-outlier
# 9719    not-outlier
# 9720    not-outlier
# 9721    not-outlier
# 9722    not-outlier
# 9723    not-outlier
# 9724    not-outlier
# 9725    not-outlier
# 9726    not-outlier
# 9727    not-outlier
# 9728    not-outlier
# 9729    not-outlier
# 9730    not-outlier
# 9731    not-outlier
# 9732    not-outlier
# 9733        outlier
# 9734        outlier
# 9735    not-outlier
# 9736        outlier
# 9737    not-outlier
# 9738    not-outlier
# 9739    not-outlier
# 9740    not-outlier
# 9741    not-outlier
# 9742    not-outlier
# 9743    not-outlier
# 9744    not-outlier
# 9745    not-outlier
# 9746    not-outlier
# 9747        outlier
# 9748    not-outlier
# 9749    not-outlier
# 9750    not-outlier
# 9751    not-outlier
# 9752    not-outlier
# 9753        outlier
# 9754    not-outlier
# 9755    not-outlier
# 9756    not-outlier
# 9757    not-outlier
# 9758    not-outlier
# 9759    not-outlier
# 9760    not-outlier
# 9761    not-outlier
# 9762    not-outlier
# 9763    not-outlier
# 9764    not-outlier
# 9765        outlier
# 9766    not-outlier
# 9767    not-outlier
# 9768    not-outlier
# 9769    not-outlier
# 9770    not-outlier
# 9771    not-outlier
# 9772    not-outlier
# 9773    not-outlier
# 9774    not-outlier
# 9775    not-outlier
# 9776    not-outlier
# 9777    not-outlier
# 9778    not-outlier
# 9779    not-outlier
# 9780    not-outlier
# 9781    not-outlier
# 9782    not-outlier
# 9783    not-outlier
# 9784    not-outlier
# 9785    not-outlier
# 9786    not-outlier
# 9787    not-outlier
# 9788    not-outlier
# 9789    not-outlier
# 9790    not-outlier
# 9791    not-outlier
# 9792    not-outlier
# 9793    not-outlier
# 9794    not-outlier
# 9795    not-outlier
# 9796    not-outlier
# 9797    not-outlier
# 9798    not-outlier
# 9799    not-outlier
# 9800    not-outlier
# 9801    not-outlier
# 9802    not-outlier
# 9803    not-outlier
# 9804    not-outlier
# 9805    not-outlier
# 9806    not-outlier
# 9807    not-outlier
# 9808    not-outlier
# 9809    not-outlier
# 9810    not-outlier
# 9811    not-outlier
# 9812    not-outlier
# 9813    not-outlier
# 9814    not-outlier
# 9815    not-outlier
# 9816    not-outlier
# 9817    not-outlier
# 9818    not-outlier
# 9819    not-outlier
# 9820    not-outlier
# 9821    not-outlier
# 9822    not-outlier
# 9823    not-outlier
# 9824    not-outlier
# 9825    not-outlier
# 9826    not-outlier
# 9827    not-outlier
# 9828    not-outlier
# 9829    not-outlier
# 9830    not-outlier
# 9831    not-outlier
# 9832        outlier
# 9833    not-outlier
# 9834    not-outlier
# 9835    not-outlier
# 9836    not-outlier
# 9837    not-outlier
# 9838    not-outlier
# 9839    not-outlier
# 9840    not-outlier
# 9841    not-outlier
# 9842    not-outlier
# 9843    not-outlier
# 9844    not-outlier
# 9845    not-outlier
# 9846    not-outlier
# 9847    not-outlier
# 9848    not-outlier
# 9849    not-outlier
# 9850    not-outlier
# 9851    not-outlier
# 9852    not-outlier
# 9853    not-outlier
# 9854    not-outlier
# 9855    not-outlier
# 9856    not-outlier
# 9857    not-outlier
# 9858    not-outlier
# 9859    not-outlier
# 9860    not-outlier
# 9861    not-outlier
# 9862    not-outlier
# 9863    not-outlier
# 9864    not-outlier
# 9865    not-outlier
# 9866    not-outlier
# 9867    not-outlier
# 9868    not-outlier
# 9869    not-outlier
# 9870    not-outlier
# 9871    not-outlier
# 9872    not-outlier
# 9873    not-outlier
# 9874    not-outlier
# 9875    not-outlier
# 9876    not-outlier
# 9877    not-outlier
# 9878    not-outlier
# 9879    not-outlier
# 9880    not-outlier
# 9881    not-outlier
# 9882    not-outlier
# 9883    not-outlier
# 9884    not-outlier
# 9885    not-outlier
# 9886    not-outlier
# 9887    not-outlier
# 9888    not-outlier
# 9889    not-outlier
# 9890    not-outlier
# 9891    not-outlier
# 9892    not-outlier
# 9893    not-outlier
# 9894        outlier
# 9895    not-outlier
# 9896    not-outlier
# 9897    not-outlier
# 9898    not-outlier
# 9899    not-outlier
# 9900    not-outlier
# 9901    not-outlier
# 9902    not-outlier
# 9903    not-outlier
# 9904    not-outlier
# 9905    not-outlier
# 9906    not-outlier
# 9907    not-outlier
# 9908    not-outlier
# 9909    not-outlier
# 9910    not-outlier
# 9911    not-outlier
# 9912    not-outlier
# 9913    not-outlier
# 9914    not-outlier
# 9915    not-outlier
# 9916    not-outlier
# 9917    not-outlier
# 9918    not-outlier
# 9919    not-outlier
# 9920    not-outlier
# 9921    not-outlier
# 9922    not-outlier
# 9923    not-outlier
# 9924    not-outlier
# 9925    not-outlier
# 9926    not-outlier
# 9927    not-outlier
# 9928    not-outlier
# 9929    not-outlier
# 9930    not-outlier
# 9931    not-outlier
# 9932    not-outlier
# 9933    not-outlier
# 9934    not-outlier
# 9935    not-outlier
# 9936        outlier
# 9937    not-outlier
# 9938    not-outlier
# 9939    not-outlier
# 9940    not-outlier
# 9941    not-outlier
# 9942    not-outlier
# 9943    not-outlier
# 9944    not-outlier
# 9945    not-outlier
# 9946    not-outlier
# 9947    not-outlier
# 9948    not-outlier
# 9949    not-outlier
# 9950    not-outlier
# 9951    not-outlier
# 9952    not-outlier
# 9953    not-outlier
# 9954    not-outlier
# 9955    not-outlier
# 9956    not-outlier
# 9957    not-outlier
# 9958    not-outlier
# 9959    not-outlier
# 9960    not-outlier
# 9961    not-outlier
# 9962    not-outlier
# 9963    not-outlier
# 9964    not-outlier
# 9965    not-outlier
# 9966    not-outlier
# 9967    not-outlier
# 9968    not-outlier
# 9969    not-outlier
# 9970    not-outlier
# 9971    not-outlier
# 9972    not-outlier
# 9973    not-outlier
# 9974    not-outlier
# 9975    not-outlier
# 9976    not-outlier
# 9977    not-outlier
# 9978    not-outlier
# 9979    not-outlier
# 9980    not-outlier
# 9981    not-outlier
# 9982    not-outlier
# 9983    not-outlier
# 9984    not-outlier
# 9985    not-outlier
# 9986    not-outlier
# 9987    not-outlier
# 9988    not-outlier
# 9989    not-outlier
# 9990    not-outlier
# 9991    not-outlier
# 9992    not-outlier
# 9993    not-outlier
# 9994    not-outlier
# 9995    not-outlier
# 9996    not-outlier
# 9997    not-outlier
# 9998    not-outlier
# 9999    not-outlier
# Name: Age, dtype: object

# %% [markdown]
# #### 3. Tenure vs Exited

# %%
hist_boxplot(data_new,'Tenure')

# %%
plot_num_category(data_new,'Tenure',TARGET)

# %%
anova(data_new,'Tenure',TARGET)
# Out:
# Conclusion: p-value 0.1615268494946745 is greater than alpha 0.05, ftest = 1.960163626100812
# There is no significant difference in the target based on the predictor.

# %% [markdown]
# #### 4. NumOfProducts vs Exited

# %%
hist_boxplot(data_new,'NumOfProducts')

# %%
plot_num_category(data_new,'NumOfProducts',TARGET)

# %%
anova(data_new,'NumOfProducts',TARGET)
# Out:
# Conclusion: p-value 1.717333004806199e-06 is less than alpha 0.05, ftest = 22.9152225029369
# There is a significant difference in the target based on the predictor.

# %%
plot_category_category(data_new,'NumOfProducts',TARGET)

# %%
chi_test(data_new,'NumOfProducts', TARGET)
# Out:
# ===== NumOfProducts =====
# Number Expected:
# [[4048.3892 1035.6108]
#  [3655.017   934.983 ]
#  [ 211.8158   54.1842]
#  [  47.778    12.222 ]]
#
# Chi-square Statistic: 1503.6293615070408, p-value: 0.0 less than 0.05
# There is a significant difference in the target based on the predictor.

# %% [markdown]
# #### 5. EstimatedSalary vs Exited

# %%
hist_boxplot(data_new,'EstimatedSalary')

# %%
plot_num_category(data_new,'EstimatedSalary',TARGET)

# %%
anova(data_new,'EstimatedSalary',TARGET)
# Out:
# Conclusion: p-value 0.22644042802263928 is greater than alpha 0.05, ftest = 1.463261923973248
# There is no significant difference in the target based on the predictor.

# %% [markdown]
# #### 6. Geography vs Exited

# %%
plot_category_category(data_new,'Geography',TARGET)

# %%
chi_test(data_new,'Geography', TARGET)
# Out:
# ===== Geography =====
# Number Expected:
# [[3992.6482 1021.3518]
#  [1997.9167  511.0833]
#  [1972.4351  504.5649]]
#
# Chi-square Statistic: 301.25533682434536, p-value: 3.8303176053541544e-66 less than 0.05
# There is a significant difference in the target based on the predictor.

# %% [markdown]
# #### 7. HasCrCard vs Exited

# %%
plot_category_category(data_new,'HasCrCard',TARGET)

# %%
chi_test(data_new,'HasCrCard', TARGET)
# Out:
# ===== HasCrCard =====
# Number Expected:
# [[2345.1035  599.8965]
#  [5617.8965 1437.1035]]
#
# Chi-square Statistic: 0.47133779904440803, p-value: 0.49237236141554686 greater than 0.05
# There is no significant difference in the target based on the predictor.

# %% [markdown]
# #### 8. IsActiveMember vs Exited

# %%
plot_category_category(data_new,'IsActiveMember',TARGET)

# %%
chi_test(data_new,'IsActiveMember', TARGET)
# Out:
# ===== IsActiveMember =====
# Number Expected:
# [[3861.2587  987.7413]
#  [4101.7413 1049.2587]]
#
# Chi-square Statistic: 242.98534164287963, p-value: 8.785858269303703e-55 less than 0.05
# There is a significant difference in the target based on the predictor.

# %% [markdown]
# #### 9.Gender vs Exited

# %%
plot_category_category(data_new,'Gender',TARGET)

# %%
chi_test(data_new,'Gender', TARGET)
# Out:
# ===== Gender =====
# Number Expected:
# [[3617.5909  925.4091]
#  [4345.4091 1111.5909]]
#
# Chi-square Statistic: 112.91857062096116, p-value: 2.2482100097131755e-26 less than 0.05
# There is a significant difference in the target based on the predictor.

# %% [markdown]
# ### Outlier Removal and Data Cleaning

# %%
def clear_outliers(df):
    # Suppress age and credit score
    for col in ["Age", "CreditScore"]:
        Q1 = df[col].quantile(0.25)
        Q3 = df[col].quantile(0.75)
        IQR = Q3 - Q1
        lower = Q1 - 1.5 * IQR
        upper = Q3 + 1.5 * IQR
        print(f"When {col} is printed below lower score: {lower} and upper score: {upper}")
        if col == "Age":
            df_outlier = df[col][(df[col] > upper)]
            df[col][df_outlier.index] = upper
        else:
            df_outlier = df[col][(df[col] < lower)]
            df[col][df_outlier.index] = lower
    return df

# %%
def outlier_process(df):
    # Process outliers
    df_outlier = lof_observation(df=df)
    df_outlier = clear_outliers(df=df_outlier)
    return df_outlier

# %%
data_outlier = data_new.copy()
data_outlier = outlier_process(df = data_outlier)
# Out:
# When Age is printed below lower score: 14.0 and upper score: 62.0
# When CreditScore is printed below lower score: 383.0 and upper score: 919.0
# /tmp/ipykernel_62840/2104514176.py:12: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col][df_outlier.index] = upper
# /tmp/ipykernel_62840/2104514176.py:15: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df[col][df_outlier.index] = lower

# %% [markdown]
# ## Feature Engineering

# %% [markdown]
# ### Credit Score

# %%
def credit_score_table(row):
    credit_score = row.CreditScore
    if credit_score < 300:
        return "Deep"
    elif credit_score < 500:
        return "Very_Poor"
    elif credit_score < 601:
        return "Poor"
    elif credit_score < 661:
        return "Fair"
    elif credit_score < 781:
        return "Good"
    elif credit_score < 851:
        return "Excellent"
    else:
        return "Top"

# %% [markdown]
# ### Age

# %%
def age_categorization(age):
    if age < 0:
        return "Invalid"
    elif age < 13:
        return "Child"
    elif age < 18:
        return "Teenager"
    elif age < 30:
        return "Young Adult"
    elif age < 60:
        return "Adult"
    else:
        return "Senior"

# %% [markdown]
# ### Age and Tenure

# %%
def age_tenure(row):
    age = row.Age
    tenure = row.Tenure
    return age*tenure

# %% [markdown]
# ### Product and Tenure

# %%
def product_utilization_rate_by_year(row):
    number_of_products = row.NumOfProducts
    tenure = row.Tenure
    
    if tenure == 0:
        return number_of_products
    else:
        rate = number_of_products / tenure
        return rate

# %% [markdown]
# ### Product and Salary

# %%
def product_utilization_rate_by_estimated_salary(row):
    number_of_products = row.NumOfProducts
    estimated_salary = row.EstimatedSalary
    
    if estimated_salary == 0:
        return "Undefined"
    else:
        rate = number_of_products / estimated_salary
        return rate

# %% [markdown]
# ### Geography and Salary

# %%
def countries_monthly_average_salaries(row):
    # Monthly average salary taken from https://www.worlddata.info/average-income.php
    avg_salaries = {'France': 3680, 'Germany': 4305, 'Spain': 2474}
    
    salary = row.EstimatedSalary / 12
    country = row.Geography
    
    if country in avg_salaries:
        return salary / avg_salaries[country]
    else:
        return None

# %% [markdown]
# ### Balance and Salary

# %%
def balance_salary(row):
    balance = row.Balance
    salary = row.EstimatedSalary
    return balance/salary

# %% [markdown]
# ### Credit Score Squared

# %%
def credit_score_squared(row):
    return (row.CreditScore)**2

# %% [markdown]
# ### Mean Financial Condition (Financial Health)

# %%
def mean_financials(row):
    credit_score = row.CreditScore
    balance = row.Balance
    estimated_salary = row.EstimatedSalary
    
    mean_financials = (credit_score + balance + estimated_salary) / 3
    return mean_financials

# %% [markdown]
# ### All Feature Engineering

# %%
def feature_engineering(df, is_show_graph=False):
    df_fe = df.copy()

    # balance_salary_rate
    df_fe['balance_salary_rate'] = df_fe.apply(lambda x: balance_salary(x), axis=1)

    # product_utilization_rate_by_year
    df_fe = df_fe.assign(product_utilization_rate_by_year=df_fe.apply(lambda x: product_utilization_rate_by_year(x), axis=1))

    # product_utilization_rate_by_estimated_salary
    df_fe = df_fe.assign(product_utilization_rate_by_estimated_salary=df_fe.apply(lambda x: product_utilization_rate_by_estimated_salary(x), axis=1))

    # tenure_rate_by_age
    df_fe['tenure_rate_by_age'] = df_fe.Tenure / (df_fe.Age - 17)

    # credit_score_rate_by_age
    df_fe['credit_score_rate_by_age'] = df_fe.CreditScore / (df_fe.Age - 17)

    # product_utilization_rate_by_salary
    df_fe['product_utilization_rate_by_salary'] = df_fe.Tenure / (df_fe.EstimatedSalary)

    # credit_score_rate_by_salary
    df_fe['credit_score_rate_by_salary'] = df_fe.CreditScore / (df_fe.EstimatedSalary)

    # mean_financials
    df_fe['mean_financials'] = df_fe.apply(lambda x: mean_financials(x), axis=1)

    # credit_score_squared
    df_fe['credit_score_squared'] = df_fe.apply(lambda x: credit_score_squared(x), axis=1)

    # age_tenure
    df_fe['age_tenure'] = df_fe.apply(lambda x: age_tenure(x), axis=1)

    # age_categorization
    df_fe['age_categorization'] = df_fe.Age.apply(lambda x: age_categorization(x))

    # credit_score_table
    df_fe = df_fe.assign(credit_score_table=df_fe.apply(lambda x: credit_score_table(x), axis=1))

    # countries_monthly_average_salaries
    df_fe = df_fe.assign(countries_monthly_average_salaries=df_fe.apply(lambda x: countries_monthly_average_salaries(x), axis=1))

    if is_show_graph:
        fig, axes = plt.subplots(nrows=2, ncols=2, figsize=(20, 12))
        fig.tight_layout()
        sns.boxplot(y='balance_salary_rate', x=TARGET, hue=TARGET, data=df_fe, ax=axes[0][0])
        sns.boxplot(y='product_utilization_rate_by_year', x=TARGET, hue=TARGET, data=df_fe, ax=axes[0][1])
        plt.ylim(-1, 5)

    return df_fe

# %%
data_feature = feature_engineering(df = data_outlier)

# %%
data_feature.head(50)
# Out:
#     RowNumber  CustomerId        Surname  CreditScore Geography  Gender  Age  \
# 0           1    15634602       Hargrave          619    France  Female   42
# 1           2    15647311           Hill          608     Spain  Female   41
# 2           3    15619304           Onio          502    France  Female   42
# 3           4    15701354           Boni          699    France  Female   39
# 4           5    15737888       Mitchell          850     Spain  Female   43
# 5           6    15574012            Chu          645     Spain    Male   44
# 6           7    15592531       Bartlett          822    France    Male   50
# 7           8    15656148         Obinna          383   Germany  Female   29
# 8           9    15792365             He          501    France    Male   44
# 9          10    15592389             H?          684    France    Male   27
# 10         11    15767821         Bearce          528    France    Male   31
# 11         12    15737173        Andrews          497     Spain    Male   24
# 12         13    15632264            Kay          476    France  Female   34
# 13         14    15691483           Chin          549    France  Female   25
# 49                      0.00400      99548.11333                602176
#
#     age_tenure age_categorization credit_score_table  \
# 0     84.00000              Adult               Fair
# 1     41.00000              Adult               Fair
# 2    336.00000              Adult               Poor
# 3     39.00000              Adult               Good
# 4     86.00000              Adult          Excellent
# 5    352.00000              Adult               Fair
# 6    350.00000              Adult          Excellent
# 7    116.00000        Young Adult          Very_Poor
# 8    176.00000              Adult               Poor
# 9     54.00000        Young Adult               Good
# 10   186.00000              Adult               Poor
# 11    72.00000        Young Adult          Very_Poor
# 12   340.00000              Adult          Very_Poor
# 13   125.00000        Young Adult               Poor
# 14   245.00000              Adult               Fair
# 15   135.00000              Adult               Fair
# 16    58.00000              Adult               Fair
# 17   216.00000        Young Adult               Poor
# 18   270.00000              Adult               Poor
# 19   144.00000        Young Adult               Good
# 20   328.00000              Adult               Good
# 21   256.00000              Adult               Fair
# 22   152.00000              Adult               Poor
# 23   138.00000              Adult               Good
# 24   190.00000              Adult          Excellent
# 25    75.00000        Young Adult               Poor
# 26    72.00000              Adult               Good
# 27   396.00000              Adult               Poor
# 28   129.00000              Adult               Poor
# 29     0.00000        Young Adult          Very_Poor
# 30   117.00000              Adult               Poor
# 31   252.00000              Adult               Poor
# 32   369.00000              Adult               Poor
# 33   252.00000              Adult               Poor
# 34   261.00000        Young Adult               Good
# 35     0.00000              Adult          Very_Poor
# 36    93.00000              Adult          Very_Poor
# 37   231.00000              Adult          Excellent
# 38   252.00000              Adult          Excellent
# 39   246.00000              Adult               Poor
# 40   160.00000              Adult          Very_Poor
# 41   408.00000              Adult          Very_Poor
# 42   122.00000             Senior               Poor
# 43    98.00000              Adult          Excellent
# 44   305.00000             Senior               Fair
# 45   128.00000              Adult               Good
# 46   243.00000        Young Adult          Excellent
# 47   351.00000              Adult               Fair
# 48    76.00000              Adult               Poor
# 49    74.00000              Adult               Good
#
#     countries_monthly_average_salaries
# 0                              2.29504
# 1                              3.79084
# 2                              2.57997
# 3                              2.12470
# 4                              2.66384
# 5                              5.04435
# 6                              0.22787
# 7                              2.31024
# 8                              1.69702
# 9                              1.62422
# 10                             1.81570
# 11                             2.57309
# 12                             0.59468
# 13                             4.32196
# 14                             2.22149
# 15                             1.24520
# 16                             0.09868
# 17                             0.48526
# 18                             5.34508
# 19                             1.23922
# 20                             3.86970
# 21                             4.66705
# 22                             4.00544
# 23                             0.19220
# 24                             4.24855
# 25                             2.81948
# 26                             3.29156
# 27                             0.87032
# 28                             1.93936
# 29                             1.21112
# 30                             4.73152
# 31                             3.54918
# 32                             1.58534
# 33                             1.15907
# 34                             4.78419
# 35                             0.63005
# 36                             3.84218
# 37                             3.31627
# 38                             0.92421
# 39                             3.44704
# 40                             2.36305
# 41                             4.10547
# 42                             2.13211
# 43                             4.40140
# 44                             5.33341
# 45                             2.44904
# 46                             2.31723
# 47                             2.27686
# 48                             1.75916
# 49                             3.75724

# %% [markdown]
# ## Data Encoding

# %%
def data_encoding(df):
    df_model = df.copy()
    
    # Categorical columns
    non_encoding_columns = ["Geography", "HasCrCard", "IsActiveMember", "Gender", "NumOfProducts", "Tenure", "credit_score_table","age_categorization"]
    df_non_encoding = df_model[non_encoding_columns]
    df_model = df_model.drop(non_encoding_columns, axis=1)
    
    df_encoding = df_non_encoding.copy()
    
    from sklearn.preprocessing import LabelEncoder
    encoder = LabelEncoder()
    df_encoding["gender_category"] = encoder.fit_transform(df_non_encoding.Gender)
    df_encoding["country_category"] = encoder.fit_transform(df_non_encoding.Geography)
    df_encoding["credit_score_category"] = encoder.fit_transform(df_non_encoding.credit_score_table)
    df_encoding["age_category"] = encoder.fit_transform(df_non_encoding.age_categorization)

    df_encoding.reset_index(drop=True, inplace=True)
    df_model.reset_index(drop=True, inplace=True)
    df_model = pd.concat([df_model, df_encoding], axis=1)

    # Drop unnecessary columns
    df_model = df_model.drop(["Geography", "Gender", "CustomerId", "Surname", "credit_score_table","age_categorization"], axis=1)

    # Encode HasCrCard and IsActiveMember as -1 for 0 values
    df_model.loc[df_model.HasCrCard == 0, 'HasCrCard'] = -1
    df_model.loc[df_model.IsActiveMember == 0, 'IsActiveMember'] = -1

    return df_model

# %%
data_encoded = data_encoding(data_feature)
data_encoded.head(20)
# Out:
#     RowNumber  CreditScore  Age      Balance  EstimatedSalary  Exited  \
# 0           1          619   42      0.00000     101348.88000       1
# 1           2          608   41  83807.86000     112542.58000       0
# 2           3          502   42 159660.80000     113931.57000       1
# 3           4          699   39      0.00000      93826.63000       0
# 4           5          850   43 125510.82000      79084.10000       0
# 5           6          645   44 113755.78000     149756.71000       1
# 6           7          822   50      0.00000      10062.80000       0
# 7           8          383   29 115046.74000     119346.88000       1
# 8           9          501   44 142051.07000      74940.50000       0
# 9          10          684   27 134603.88000      71725.73000       0
# 10         11          528   31 102016.72000      80181.12000       0
# 11         12          497   24      0.00000      76390.01000       0
# 12         13          476   34      0.00000      26260.98000       0
# 13         14          549   25      0.00000     190857.79000       0
# 14         15          635   35      0.00000      65951.65000       0
# 15         16          616   45 143129.41000      64327.26000       0
# 16         17          653   58 132602.88000       5097.67000       1
# 17         18          549   24      0.00000      14406.41000       0
# 18         19          587   45      0.00000     158684.81000       0
# 19         20          726   24      0.00000      54724.03000       0
#
#     balance_salary_rate  product_utilization_rate_by_year  \
# 0               0.00000                           0.50000
# 1               0.74468                           1.00000
# 2               1.40137                           0.37500
# 3               0.00000                           2.00000
# 4               1.58706                           0.50000
# 5               0.75960                           0.25000
# 6               0.00000                           0.28571
# 7               0.96397                           1.00000
# 8               1.89552                           0.50000
# 9               1.87665                           0.50000
# 10              1.27233                           0.33333
# 11              0.00000                           0.66667
# 12              0.00000                           0.20000
# 13              0.00000                           0.40000
# 14              0.00000                           0.28571
# 15              2.22502                           0.66667
# 16             26.01245                           1.00000
# 17              0.00000                           0.22222
# 18              0.00000                           0.16667
# 19              0.00000                           0.33333
#
#     product_utilization_rate_by_estimated_salary  tenure_rate_by_age  \
# 0                                        0.00001             0.08000
# 1                                        0.00001             0.04167
# 2                                        0.00003             0.32000
# 3                                        0.00002             0.04545
# 4                                        0.00001             0.07692
# 4         1.00000  2.00000                0                 2
# 5         2.00000  8.00000                1                 2
# 6         2.00000  7.00000                1                 0
# 7         4.00000  4.00000                0                 1
# 8         2.00000  4.00000                1                 0
# 9         1.00000  2.00000                1                 0
# 10        2.00000  6.00000                1                 0
# 11        2.00000  3.00000                1                 2
# 12        2.00000 10.00000                0                 0
# 13        2.00000  5.00000                0                 0
# 14        2.00000  7.00000                0                 2
# 15        2.00000  3.00000                1                 1
# 16        1.00000  1.00000                1                 1
# 17        2.00000  9.00000                0                 2
# 18        1.00000  6.00000                1                 2
# 19        2.00000  6.00000                0                 0
#
#     credit_score_category  age_category
# 0                       1             0
# 1                       1             0
# 2                       3             0
# 3                       2             0
# 4                       0             0
# 5                       1             0
# 6                       0             0
# 7                       4             2
# 8                       3             0
# 9                       2             2
# 10                      3             0
# 11                      4             2
# 12                      4             0
# 13                      3             2
# 14                      1             0
# 15                      1             0
# 16                      1             0
# 17                      3             2
# 18                      3             0
# 19                      2             2

# %% [markdown]
# ## Correlation Analysis

# %%
correlation = data_encoded.corr().abs()
plt.figure(figsize=(20,20))
sns.heatmap(correlation, annot=True)
plt.show()

# %%
corrs_results = data_encoded.corrwith(data_encoded["Exited"]).abs().nlargest(24)
corrs_results
# Out:
# Exited                                         1.00000
# Age                                            0.31293
# IsActiveMember                                 0.15588
# credit_score_rate_by_age                       0.13949
# age_category                                   0.12634
# Balance                                        0.11865
# tenure_rate_by_age                             0.11274
# age_tenure                                     0.10626
# gender_category                                0.10624
# mean_financials                                0.09481
# NumOfProducts                                  0.04775
# country_category                               0.03575
# CreditScore                                    0.02617
# balance_salary_rate                            0.02557
# credit_score_squared                           0.02347
# product_utilization_rate_by_salary             0.02030
# credit_score_rate_by_salary                    0.01918
# countries_monthly_average_salaries             0.01811
# RowNumber                                      0.01623
# credit_score_category                          0.01618
# product_utilization_rate_by_estimated_salary   0.01531
# Tenure                                         0.01378
# EstimatedSalary                                0.01211
# HasCrCard                                      0.00720
# dtype: float64

# %% [markdown]
# ## Model Utilization

# %%
def model_prepare(df_model):
    y = df_model[TARGET]
    X = df_model.drop(TARGET, axis=1)
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=32)
    
    from sklearn.preprocessing import StandardScaler
    sc = StandardScaler()
    X_train = sc.fit_transform(X_train)
    X_test = sc.transform(X_test)
    
    return X_train, X_test, y_train, y_test

# %%
# model_prepare test, train split 0.3
X_train, X_test, y_train, y_test = model_prepare(df_model = data_encoded)

# %% [markdown]
# ### Logistic Regression

# %%
logr_model = LogisticRegression()
logr_model.fit(X_train, y_train)
y_pred = logr_model.predict(X_test)
accuracy = accuracy_score(y_test, y_pred)

print(classification_report(y_test, y_pred, digits=4))
print(f"Accuracy score of Logistic Regression: {accuracy:.4f}")
# Out:
#               precision    recall  f1-score   support
#
#            0     0.8307    0.9692    0.8946      2405
#            1     0.6186    0.2017    0.3042       595
#
#     accuracy                         0.8170      3000
#    macro avg     0.7246    0.5855    0.5994      3000
# weighted avg     0.7886    0.8170    0.7775      3000
#
# Accuracy score of Logistic Regression: 0.8170

# %% [markdown]
# ### Model with Training

# %%
def data_training(X_train, X_test, y_train, y_test):
    models = [
        ('LOGR', LogisticRegression()),
        ('KNN', KNeighborsClassifier()),
        ('CART', DecisionTreeClassifier()),
        ('RF', RandomForestClassifier()),
        ('GBM', GradientBoostingClassifier()),
        ('XGBoost', XGBClassifier()),
        ('LightGBM', LGBMClassifier()),
        ('CatBoost', CatBoostClassifier(verbose=0))
    ]

    df_result = pd.DataFrame(columns=["model", "accuracy_score", "scale_method", "0_precision", "0_recall", "1_precision", "1_recall"])
    for name, model in models:
        model.fit(X_train, y_train)
        y_pred = model.predict(X_test)
        score = accuracy_score(y_test, y_pred)
        class_report = classification_report(y_test, y_pred, digits=2, output_dict=True)
        zero_report = class_report['0']
        one_report = class_report['1']
        df_result = pd.concat([df_result, pd.DataFrame({
            'model': [name],
            'accuracy_score': [score],
            'scale_method': ['NA'],
            '0_precision': [zero_report['precision']],
            '0_recall': [zero_report['recall']],
            '1_precision': [one_report['precision']],
            '1_recall': [one_report['recall']]
        })], ignore_index=True)

    return df_result.sort_values("accuracy_score", ascending=False)

# %%
training_result = data_training(X_train, X_test, y_train, y_test)
training_result
# Out:
#       model  accuracy_score scale_method  0_precision  0_recall  1_precision  \
# 4       GBM         0.86200           NA      0.87637   0.96383      0.75493
# 7  CatBoost         0.86033           NA      0.88017   0.95593      0.72680
# 3        RF         0.85433           NA      0.86799   0.96507      0.74233
# 6  LightGBM         0.85400           NA      0.87841   0.94927      0.69576
# 5   XGBoost         0.84567           NA      0.87723   0.93888      0.65493
# 1       KNN         0.82167           NA      0.84914   0.94553      0.59317
# 0      LOGR         0.81700           NA      0.83072   0.96923      0.61856
# 2      CART         0.77067           NA      0.87473   0.83326      0.43441
#
#    1_recall
# 4   0.45042
# 7   0.47395
# 3   0.40672
# 6   0.46891
# 5   0.46891
# 1   0.32101
# 0   0.20168
# 2   0.51765

# %% [markdown]
# ## Hyperparameter Tuning

# %% [markdown]
# ### XGBoost

# %%
'''
xgb_model = XGBClassifier(objective='reg:logistic', eval_metric="logloss")

param_grid = {
    'learning_rate': [0.3, 0.31, 0.32],
    'max_depth': [5,6,7,8,9,10],
    'n_estimators': [30,40, 50, 60, 70]
}

grid_search = GridSearchCV(estimator=xgb_model, param_grid=param_grid, cv=5)
grid_search.fit(X_train, y_train)

print("Best parameters: ", grid_search.best_params_)
'''
# Out:
# '\nxgb_model = XGBClassifier(objective=\'reg:logistic\', eval_metric="logloss")\n\nparam_grid = {\n    \'learning_rate\': [0.3, 0.31, 0.32],\n    \'max_depth\': [5,6,7,8,9,10],\n    \'n_estimators\': [30,40, 50, 60, 70]\n}\n\ngrid_search = GridSearchCV(estimator=xgb_model, param_grid=param_grid, cv=5)\ngrid_search.fit(X_train, y_train)\n\nprint("Best parameters: ", grid_search.best_params_)\n'

# %%
xgb_model=XGBClassifier(silent=0, learning_rate=0.32, max_delta_step=7,
                            objective='reg:logistic',n_estimators=40, 
                            max_depth=3, eval_metric="logloss", gamma=3,base_score=0.5)
xgb_model.fit(X_train, y_train)
y_pred = xgb_model.predict(X_test)
print(classification_report(y_test,y_pred,digits=2))
print("Accuracy score of Tuned XGBoost Regression: ", accuracy_score(y_test, y_pred))
# Out:
# [22:22:19] WARNING: ../src/learner.cc:767:
# Parameters: { "silent" } are not used.
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91      2365
#            1       0.74      0.47      0.58       635
#
#     accuracy                           0.85      3000
#    macro avg       0.81      0.71      0.74      3000
# weighted avg       0.84      0.85      0.84      3000
#
# Accuracy score of Tuned XGBoost Regression:  0.8533333333333334

# %% [markdown]
# ### Random Forest

# %%
'''
param_grid = {'max_depth': [3, 5, 6, 7, 8], 'max_features': [2,4,6,7,8,9],'n_estimators' : [50,100], 'min_samples_split': [3, 5, 6, 7]}
randFor_grid = GridSearchCV(RandomForestClassifier(), param_grid, cv = 5, refit = True, verbose = 0)
randFor_grid.fit(X_train,y_train)
best_model(randFor_grid)
'''
# Out:
# "\nparam_grid = {'max_depth': [3, 5, 6, 7, 8], 'max_features': [2,4,6,7,8,9],'n_estimators' : [50,100], 'min_samples_split': [3, 5, 6, 7]}\nrandFor_grid = GridSearchCV(RandomForestClassifier(), param_grid, cv = 5, refit = True, verbose = 0)\nrandFor_grid.fit(X_train,y_train)\nbest_model(randFor_grid)\n"

# %%
rnd_model = RandomForestClassifier(max_depth=10, max_features=14, min_samples_split=11,n_estimators=75)
rnd_model.fit(X_train, y_train)
y_pred = rnd_model.predict(X_test)
print(classification_report(y_test,y_pred,digits=2))
print("Accuracy score of tuned Random Forest model: ", accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92      2405
#            1       0.75      0.43      0.54       595
#
#     accuracy                           0.86      3000
#    macro avg       0.81      0.70      0.73      3000
# weighted avg       0.85      0.86      0.84      3000
#
# Accuracy score of tuned Random Forest model:  0.858

# %% [markdown]
# ### LightBGM

# %%
lgbm_model = LGBMClassifier(silent = 0, learning_rate = 0.08, max_delta_step = 1, n_estimators = 45, boosting_type = 'gbdt',
                            max_depth = 5)
lgbm_model.fit(X_train, y_train)
y_pred = lgbm_model.predict(X_test)
print(classification_report(y_test, y_pred, digits=2))
print("Accuracy score of tuned LightGBM model: ", accuracy_score(y_test, y_pred))
# Out:
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Warning] Accuracy may be bad since you didn't explicitly set num_leaves OR 2^max_depth > num_leaves. (num_leaves=31).
# [LightGBM] [Info] Number of positive: 1441, number of negative: 5556
# [LightGBM] [Warning] Auto-choosing col-wise multi-threading, the overhead of testing was 0.018057 seconds.
# You can set `force_col_wise=true` to remove the overhead.
# [LightGBM] [Info] Total Bins 3662
# [LightGBM] [Info] Number of data points in the train set: 6997, number of used features: 24
# [LightGBM] [Info] [binary:BoostFromScore]: pavg=0.205945 -> initscore=-1.349541
# [LightGBM] [Info] Start training from score -1.349541
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
# [LightGBM] [Warning] No further splits with positive gain, best gain: -inf
#               precision    recall  f1-score   support
#
#            0       0.87      0.97      0.92      2405
#            1       0.77      0.42      0.54       595
#
#     accuracy                           0.86      3000
#    macro avg       0.82      0.69      0.73      3000
# weighted avg       0.85      0.86      0.84      3000
#
# Accuracy score of tuned LightGBM model:  0.86

# %% [markdown]
# ## Parameter and More Function

# %%
# Function to display the best model score and parameters
def display_best_model(model):
    print(f"Best score: {model.best_score_}")
    print(f"Best parameters: {model.best_params_}")
    print(f"Best estimator: {model.best_estimator_}")

# Function to calculate AUC score and ROC curve
def calculate_auc_scores(y_actual, y_pred_prob):
    auc_score = roc_auc_score(y_actual, y_pred_prob)
    fpr, tpr, _ = roc_curve(y_actual, y_pred_prob)
    return auc_score, fpr, tpr

# Function to plot confusion matrix
def plot_confusion_matrix(cm, classes, normalize=False, title='Confusion matrix', cmap=plt.cm.Blues):
    plt.rcParams.update({'font.size': 16})
    
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)
    
    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45, color="blue")
    plt.yticks(tick_marks, classes, color="blue")

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt), horizontalalignment="center", color="red" if cm[i, j] > thresh else "black")

    plt.tight_layout()
    plt.ylabel('True label')
    plt.xlabel('Predicted label')

# Function to handle infinite values in a DataFrame
def handle_infinite_values(df):
    indices_to_keep = ~df.isin([np.nan, np.inf, -np.inf]).any(1)
    return df[indices_to_keep].astype(np.float64)

# %% [markdown]
# ### Confussion Matrix

# %%
cfm = confusion_matrix(y_test, y_pred=y_pred)
plot_confusion_matrix(cfm, classes=['Non Churn','Churn'],
                      title='Churn Confusion matrix')


tn, fp, fn, tp = cfm.ravel()
print("True Negatives: ",tn)
print("False Positives: ",fp)
print("False Negatives: ",fn)
print("True Positives: ",tp)
# Out:
# Confusion matrix, without normalization
# [[2330   75]
#  [ 345  250]]
# True Negatives:  2330
# False Positives:  75
# False Negatives:  345
# True Positives:  250

# %% [markdown]
# ### ROC Curve

# %%
y_pred_proba = lgbm_model.predict_proba(X_test)
skplt.metrics.plot_roc_curve(y_test, y_pred_proba, figsize=(8,8))

plt.show()

# %% [markdown]
# ### Feature Importance

# %%
feature_index = data_encoded.loc[:, data_encoded.columns != TARGET]

feature_importance = pd.Series(xgb_model.feature_importances_, 
                               index=feature_index.columns).sort_values(ascending=False)
sns.barplot(x = feature_importance, y = feature_importance.index, color='r', saturation=1)
plt.xlabel('Variable Severity Scores')
plt.ylabel('Variables')
plt.title('Variable Severity Levels')
plt.show()

# %% [markdown]
# ## Pipeline

# %%
from sklearn.pipeline import Pipeline

X_train, X_test, y_train, y_test = model_prepare(df_model = data_encoded)

pipe = Pipeline([('xgboost', xgb_model)])

pipe.fit(X_train,y_train)
y_pred = pipe.predict(X_test)

print(classification_report(y_test,y_pred,digits=2))
print("Accuracy score of Tuned XGBoost Regression: ", accuracy_score(y_test, y_pred))
# Out:
# [20:55:04] WARNING: ../src/learner.cc:767:
# Parameters: { "silent" } are not used.
#
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91      2365
#            1       0.74      0.47      0.58       635
#
#     accuracy                           0.85      3000
#    macro avg       0.81      0.71      0.74      3000
# weighted avg       0.84      0.85      0.84      3000
#
# Accuracy score of Tuned XGBoost Regression:  0.8533333333333334

# %%
with open('pipeline.pickle','wb') as f:
    pickle.dump(pipe, f)

with open('pipeline.pickle','rb') as f:
    loaded_pipe = pickle.load(f)
    
y_pred = loaded_pipe.predict(X_test)

print(classification_report(y_test,y_pred,digits=2))
print("Accuracy score of Tuned XGBoost Regression: ", accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91      2365
#            1       0.74      0.47      0.58       635
#
#     accuracy                           0.85      3000
#    macro avg       0.81      0.71      0.74      3000
# weighted avg       0.84      0.85      0.84      3000
#
# Accuracy score of Tuned XGBoost Regression:  0.8533333333333334

# %%
def prediction(model, df):
    data_feature = feature_engineering(df)
    data_encoded = data_encoding(data_feature)
    
    prediction = model.predict(data_encoded)
    
    df['ExitedPred'] = prediction.tolist()

    return prediction

# %%
results =prediction(loaded_pipe,data_outlier.drop(TARGET, axis=1))

results[0]
# Out:
# 0

# %%
print(prediction)

# %%
with open('churn_model.pkl','wb') as f:
    pickle.dump(xgb_model, f)

with open('churn_model.pkl','rb') as f:
    loaded_pipe = pickle.load(f)
    
y_pred = loaded_pipe.predict(X_test)

print(classification_report(y_test,y_pred,digits=2))
print("Accuracy score of Tuned XGBoost Regression: ", accuracy_score(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.87      0.96      0.91      2365
#            1       0.74      0.47      0.58       635
#
#     accuracy                           0.85      3000
#    macro avg       0.81      0.71      0.74      3000
# weighted avg       0.84      0.85      0.84      3000
#
# Accuracy score of Tuned XGBoost Regression:  0.8533333333333334

# %%
test = data.drop("Exited", axis=1).iloc[4].to_dict()
test
# Out:
# {'RowNumber': 5,
#  'CustomerId': 15737888,
#  'Surname': 'Mitchell',
#  'CreditScore': 850,
#  'Geography': 'Spain',
#  'Gender': 'Female',
#  'Age': 43,
#  'Tenure': 2,
#  'Balance': 125510.82,
#  'NumOfProducts': 1,
#  'HasCrCard': 1,
#  'IsActiveMember': 1,
#  'EstimatedSalary': 79084.1}

# %%
df = pd.DataFrame(test, index = [0])
df
# Out:
#    RowNumber  CustomerId   Surname  CreditScore Geography  Gender  Age  \
# 0          5    15737888  Mitchell          850     Spain  Female   43
#
#    Tenure      Balance  NumOfProducts  HasCrCard  IsActiveMember  \
# 0       2 125510.82000              1          1               1
#
#    EstimatedSalary
# 0      79084.10000
